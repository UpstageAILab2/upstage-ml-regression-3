# %% [markdown]
# ### Import library

# %%
# visualization
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')
import seaborn as sns

# utils
import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle
import warnings;warnings.filterwarnings('ignore')
import gdown
import joblib

# Model
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import lightgbm as lgb

import eli5
from eli5.sklearn import PermutationImportance

import os
import glob

# 코드 셀 실행 후 경고를 무시
# import warnings
# warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Data Load

# %%
train_path = '/root/train.csv'
test_path  = '/root/test.csv'
dt = pd.read_csv(train_path)
dt_test = pd.read_csv(test_path)

# %%
dt['구'] = dt['시군구'].map(lambda x : x.split()[1])
dt['동'] = dt['시군구'].map(lambda x : x.split()[2])

dt_test['구'] = dt_test['시군구'].map(lambda x : x.split()[1])
dt_test['동'] = dt_test['시군구'].map(lambda x : x.split()[2])

# %%
mean_val_by_gu = dt.groupby("구")["target"].mean().sort_values(ascending=False)
mean_val_by_dong = dt.groupby("동")["target"].mean().sort_values(ascending=False)
std_val_by_gu = dt.groupby("구")["target"].std().sort_values(ascending=False)
std_val_by_dong = dt.groupby("동")["target"].std().sort_values(ascending=False)

# %% [markdown]
# ### Data preprocessing

# %%
# train/test 구분을 위한 칼럼을 하나 만들어 줍니다.
dt['is_test'] = 0
dt_test['is_test'] = 1
df = pd.concat([dt, dt_test])     # 하나의 데이터로 만들어줍니다.

# %%
# 필요 없어 보이는 columns 제거
drop_col = ['부번', 'k-전화번호', 'k-팩스번호', 'k-관리방식', 'k-복도유형', 'k-시행사', 'k-사용검사일-사용승인일', 'k-홈페이지', 'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태', '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '단지신청일', 'k-관리비부과면적', '주차대수', '건축면적', '해제사유발생일', '단지소개기존clob', 'k-135㎡초과', '중개사소재지', '등기신청일자', '거래유형']
df.drop(drop_col, axis=1, inplace=True)

# %%
# 시군구 feaeture 처리
# 구와 동에 대한 Feature 수정
# df['구'] = df['시군구'].apply(lambda x:x.split()[1])
# df['동'] = df['시군구'].apply(lambda x:x.split()[2])
omg = ['용산구', '강남구', '서초구', '송파구', '성동구', '종로구']
is_omg = []
for x in df['구'].tolist():
    if x in omg:
        is_omg.append(1)
    else:
        is_omg.append(0)
df['개비싸'] = is_omg
df.loc[~df['구'].isin(omg), '동'] = 'Unknown' 

# del df['시군구']

# %%
# df['계약년'] = df['계약년월'].astype('str').map(lambda x : x[:4])
# df['계약월'] = df['계약년월'].astype('str').map(lambda x : x[4:])

# %%
df['계약년'] = df['계약년월'].map(lambda x : x // 100)
df['계약월'] = df['계약년월'].map(lambda x : x % 100)

df["date"] = pd.to_datetime(df['계약년'].astype(str) + '-' + df['계약월'].astype(str) + '-' + df['계약일'].astype(str))

# %%
df['is_public'] = df["k-전용면적별세대현황(60㎡이하)"].notnull()

# %%
df.columns
# Out:
# Index(['시군구', '번지', '본번', '아파트명', '전용면적(㎡)', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-단지분류(아파트,주상복합등등)', 'k-세대타입(분양형태)', 'k-난방방식', 'k-전체동수', 'k-전체세대수',
#        'k-건설사(시공사)', 'k-연면적', 'k-주거전용면적', 'k-전용면적별세대현황(60㎡이하)',
#        'k-전용면적별세대현황(60㎡~85㎡이하)', 'k-85㎡~135㎡이하', '좌표X', '좌표Y', 'target', '구',
#        '동', 'is_test', '개비싸', '계약년', '계약월', 'date', 'is_public'],
#       dtype='object')

# %%
drop_cols_k = ['k-단지분류(아파트,주상복합등등)', 'k-세대타입(분양형태)',  'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-연면적']

df.drop(columns=drop_cols_k, inplace=True)

# %%
# 본번, 부번의 경우 float로 되어있지만 범주형 변수의 의미를 가지므로 object(string) 형태로 바꾸어주고 아래 작업을 진행하겠습니다.
df['본번'] = df['본번'].astype('str')

# %%
order1_mean_gu = mean_val_by_gu.index.tolist()
order2_mean_dong = mean_val_by_dong.index.tolist()
order3_std_gu = std_val_by_gu.index.tolist()
order4_std_dong = std_val_by_dong.index.tolist()

# %%
# Create a dictionary to map district names to their corresponding label encoded values
gu_mapping1 = {district: label for label, district in enumerate(order1_mean_gu)}
gu_mapping2 = {district: label for label, district in enumerate(order3_std_gu)}
dong_mapping1 = {dong: label for label, dong in enumerate(order2_mean_dong)}
dong_mapping2 = {dong: label for label, dong in enumerate(order4_std_dong)}

df['구_encoded'] = df["구"].map(gu_mapping1)
df['구_std'] = df["구"].map(gu_mapping2)
df['동_encoded'] = df["동"].map(dong_mapping1)
df['동_std'] = df["동"].map(dong_mapping2)

# %%
seoul_bds = ["강남구", "영등포구", "용산구"]

df["has_bds"] = df["구"].apply(lambda x : 1 if x in seoul_bds else 0)

# %%
df['yrs_diff_built_contract'] = df['계약년'] - df['건축년도']
df['built_in3yrs'] = df['yrs_diff_built_contract'].apply(lambda x : 1 if x <= 3 else 0)
df['built_in5yrs'] = df['yrs_diff_built_contract'].apply(lambda x : 1 if x <= 5 else 0)
df['built_over30yrs'] = df['yrs_diff_built_contract'].apply(lambda x : 1 if x >= 30 else 0)
df['built_over35yrs'] = df['yrs_diff_built_contract'].apply(lambda x : 1 if x >= 35 else 0)
df['built_over40yrs'] = df['yrs_diff_built_contract'].apply(lambda x : 1 if x >= 40 else 0)

# %%
df['road'] = df['도로명'].apply(lambda x : x.split()[0] if len(x.split()) > 0 else x)
df['on_main_st'] = df['road'].apply(lambda x: not any(char.isdigit() for char in x))
del df['road']

# %% [markdown]
# #### extra data

# %% [markdown]
# ##### 구별 특성

# %% [markdown]
# - 시군구 단위 용도지역 현황 (2022)

# %%
df_zones_original = pd.read_csv("./extra_data/2022_zoning_seoul.csv", encoding='euc-kr')

# %%
df_zones_original['주거지역_전용주거_비율'] = df_zones_original['주거지역_전용주거_소계'] / df_zones_original['도시지역 면적']
df_zones_original['주거지역_일반주거_비율'] = df_zones_original['주거지역_일반주거지역_소계'] / df_zones_original['도시지역 면적']
df_zones_original['주거지역_준주거_비율'] = df_zones_original['주거지역_준주거지역'] / df_zones_original['도시지역 면적']
df_zones_original['중심상업_비율'] = df_zones_original['상업지역_중심상업'] / df_zones_original['도시지역 면적']
df_zones_original['일반상업_비율'] = df_zones_original['상업지역_일반상업'] / df_zones_original['도시지역 면적']
df_zones_original['근린상업_비율'] = df_zones_original['상업지역_근린상업'] / df_zones_original['도시지역 면적']

# %%
df_zone_ratio = df_zones_original[['시군구', '주거지역_비율', '상업지역_비율', '공업지역_비율', '녹지지역_비율', '주거지역_전용주거_비율', '주거지역_일반주거_비율', '주거지역_준주거_비율',
       '중심상업_비율', '일반상업_비율', '근린상업_비율']]

# %%
df_zone_ratio.rename(columns={'시군구': '구'}, inplace=True)

# %%
df = pd.merge(left=df, right=df_zone_ratio, on='구', how='left')

# %% [markdown]
# - 2022_학생_1만명당_사설학원수

# %%
df_academies = pd.read_csv("extra_data/2022_학생_1만명당_사설학원수_20240326124719.csv", encoding='euc-kr')

# %%
df_academies.rename(columns={"자치구":"구"}, inplace=True)
df_academies.drop(columns=['초중고_학생수(명)', '사설학원수(개소)'], inplace=True)

# %%
df = pd.merge(left=df, right=df_academies, on='구', how='left')

# %% [markdown]
# #### 경제지표

# %% [markdown]
# - 기준금리

# %%
df_interest_rate = pd.read_csv("./extra_data/base_rate.csv")

# %%
df_interest_rate.rename(columns={'날짜': 'date'}, inplace=True)
df_interest_rate['date'] = pd.to_datetime(df_interest_rate['date'])

# %%
df = pd.merge(df, df_interest_rate, on = 'date', how='left')

# %% [markdown]
# - KOSPI

# %%
# Use glob to find all files that match the pattern
file_paths = glob.glob("./extra_data/KOSPI_*.csv")

# Initialize an empty list to store the dataframes
dfs = []

# Iterate over the file paths and read each CSV file into a dataframe
for file_path in file_paths:
    kospi_df_yr = pd.read_csv(file_path, encoding="euc-kr")
    dfs.append(kospi_df_yr)

# %%
kospi_df = pd.concat(dfs, ignore_index=True)
kospi_df = kospi_df.drop(columns=['시가', '고가', '저가'])

# %%
kospi_df.rename(columns={"일자":"date", "종가":"Close"}, inplace=True)
kospi_df["date"] = kospi_df['date'].str.replace('/', '-')
kospi_df["date"] = pd.to_datetime(kospi_df["date"])
kospi_df.sort_values(by='date', ascending=True, inplace=True)

# %%
kospi_df["KOSPI_MA5d"] = kospi_df["Close"].transform(lambda x: x.rolling(window=5).mean())
kospi_df["KOSPI_MA20d"] = kospi_df["Close"].transform(lambda x: x.rolling(window=20).mean())
kospi_df["KOSPI_MA60d"] = kospi_df["Close"].transform(lambda x: x.rolling(window=60).mean())
kospi_df["KOSPI_MA120d"] = kospi_df["Close"].transform(lambda x: x.rolling(window=120).mean())

# %%
kospi_df["Close_delay120d"] = kospi_df["Close"].shift(120)

# %%
df = pd.merge(left=df, right=kospi_df, on='date', how='left')

# %%
kospi_df.drop(columns='date', inplace=True)

# %%
df[kospi_df.columns.tolist()] = df[kospi_df.columns.tolist()].interpolate(method='linear', axis=0)

# %% [markdown]
# - unempl

# %%
unempl_rate = pd.read_csv("./extra_data/서울시_월별실업률_2007_2024.csv", encoding="euc-kr")

# %%
unempl_rate["시점"] = unempl_rate["시점"]*100
unempl_rate["시점"] = unempl_rate["시점"].astype(int)
unempl_rate.rename(columns={"계" : "unempl_rate_total", "남자": "unempl_male", "여자":"unempl_female"}, inplace=True)

# %%
df = pd.merge(left=df, right=unempl_rate, left_on="계약년월", right_on="시점", how="left")
df.drop(columns=['시점'], inplace=True)

# %% [markdown]
# #### del cols before modeling

# %%
df.columns
# Out:
# Index(['시군구', '번지', '본번', '아파트명', '전용면적(㎡)', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-주거전용면적', 'k-전용면적별세대현황(60㎡이하)', 'k-전용면적별세대현황(60㎡~85㎡이하)',
#        'k-85㎡~135㎡이하', '좌표X', '좌표Y', 'target', '구', '동', 'is_test', '개비싸',
#        '계약년', '계약월', 'date', 'is_public', '구_encoded', '구_std', '동_encoded',
#        '동_std', 'has_bds', 'yrs_diff_built_contract', 'built_in3yrs',
#        'built_in5yrs', 'built_over30yrs', 'built_over35yrs', 'built_over40yrs',
#        'on_main_st', '주거지역_비율', '상업지역_비율', '공업지역_비율', '녹지지역_비율',
#        '주거지역_전용주거_비율', '주거지역_일반주거_비율', '주거지역_준주거_비율', '중심상업_비율', '일반상업_비율',
#        '근린상업_비율', '학생1만명당_사설학원수(개소)', '기준금리', 'Close', '대비', '등락률', '거래량',
#        '거래대금', '상장시가총액', 'KOSPI_MA5d', 'KOSPI_MA20d', 'KOSPI_MA60d',
#        'KOSPI_MA120d', 'Close_delay120d', 'unempl_rate_total', 'unempl_male',
#        'unempl_female'],
#       dtype='object')

# %%
drop_cols_before_train = ['date', '좌표X', '좌표Y', '구', '동', '계약월', '계약일', '계약년']

df.drop(columns=drop_cols_before_train, inplace=True)

df.columns = df.columns.str.replace('[^\w\s]', '')
df.columns = df.columns.str.replace(' ', '_')

# %%
df['k전용면적별세대현황60이하'] = df['k전용면적별세대현황60이하'].fillna(0)
df['k전용면적별세대현황6085이하'] = df['k전용면적별세대현황6085이하'].fillna(0)
df['k85135이하'] = df['k85135이하'].fillna(0)

# %%
# 'time_col' 데이터를 문자열 형태로 변환
df['계약년월'] = df['계약년월'].astype(str)
# 문자열 형태 데이터를 datetime 형태로 변환
df['계약년월'] = pd.to_datetime(df['계약년월'], format='%Y%m')
# 변환 확인
print(df['계약년월'].head())
# Out:
# 0   2017-12-01
# 1   2017-12-01
# 2   2017-12-01
# 3   2018-01-01
# 4   2018-01-01
# Name: 계약년월, dtype: datetime64[ns]

# %%
# 먼저, 연속형 변수와 범주형 변수를 위 info에 따라 분리해주겠습니다.
continuous_columns = []
categorical_columns = []

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        continuous_columns.append(column)
    else:
        categorical_columns.append(column)

print("연속형 변수:", continuous_columns)
print("범주형 변수:", categorical_columns)

# 수치형 데이터를 어떻게 채워야 될지 모르겠음 -> 걍 빼.
# 좌표X, 좌표Y 를 리니어로 채우는건 혼동을 줄 수 있는 데이터임
df.drop(columns=['k주거전용면적'], inplace=True)

# 범주형 변수에 대한 보간
df[categorical_columns] = df[categorical_columns].fillna('NULL')
# Out:
# 연속형 변수: ['전용면적', '층', '건축년도', 'k주거전용면적', 'k전용면적별세대현황60이하', 'k전용면적별세대현황6085이하', 'k85135이하', 'target', 'is_test', '개비싸', 'is_public', '구_encoded', '구_std', '동_encoded', '동_std', 'has_bds', 'yrs_diff_built_contract', 'built_in3yrs', 'built_in5yrs', 'built_over30yrs', 'built_over35yrs', 'built_over40yrs', 'on_main_st', '주거지역_비율', '상업지역_비율', '공업지역_비율', '녹지지역_비율', '주거지역_전용주거_비율', '주거지역_일반주거_비율', '주거지역_준주거_비율', '중심상업_비율', '일반상업_비율', '근린상업_비율', '학생1만명당_사설학원수개소', '기준금리', 'Close', '대비', '등락률', '거래량', '거래대금', '상장시가총액', 'KOSPI_MA5d', 'KOSPI_MA20d', 'KOSPI_MA60d', 'KOSPI_MA120d', 'Close_delay120d', 'unempl_rate_total', 'unempl_male', 'unempl_female']
# 범주형 변수: ['시군구', '번지', '본번', '아파트명', '계약년월', '도로명']

# %% [markdown]
# # Train

# %%
df_train = df.loc[df['is_test']==0, :]
df_test = df.loc[df['is_test']==1, :]

df_train.drop(['is_test'], axis=1, inplace=True)
df_test.drop(['is_test'], axis=1, inplace=True)
print(df_train.shape, df_test.shape)
# Out:
# (1118822, 53) (9272, 53)

# %%
# dt_test의 target은 일단 0으로 임의로 채워주도록 하겠습니다.
df_test['target'] = 0

# %%
# 변수 삭제 및 파생변수 제작으로 추가된 변수들이 존재하기에, 다시한번 연속형과 범주형 칼럼을 분리해주겠습니다.
continuous_columns_v2 = []
categorical_columns_v2 = []

for column in df_train.columns:
    if column == '계약년월':
        continue
    if pd.api.types.is_numeric_dtype(df_train[column]):
        continuous_columns_v2.append(column)
    else:
        categorical_columns_v2.append(column)

print("연속형 변수:", continuous_columns_v2)
print("범주형 변수:", categorical_columns_v2)
# Out:
# 연속형 변수: ['전용면적', '층', '건축년도', 'k전용면적별세대현황60이하', 'k전용면적별세대현황6085이하', 'k85135이하', 'target', '개비싸', 'is_public', '구_encoded', '구_std', '동_encoded', '동_std', 'has_bds', 'yrs_diff_built_contract', 'built_in3yrs', 'built_in5yrs', 'built_over30yrs', 'built_over35yrs', 'built_over40yrs', 'on_main_st', '주거지역_비율', '상업지역_비율', '공업지역_비율', '녹지지역_비율', '주거지역_전용주거_비율', '주거지역_일반주거_비율', '주거지역_준주거_비율', '중심상업_비율', '일반상업_비율', '근린상업_비율', '학생1만명당_사설학원수개소', '기준금리', 'Close', '대비', '등락률', '거래량', '거래대금', '상장시가총액', 'KOSPI_MA5d', 'KOSPI_MA20d', 'KOSPI_MA60d', 'KOSPI_MA120d', 'Close_delay120d', 'unempl_rate_total', 'unempl_male', 'unempl_female']
# 범주형 변수: ['시군구', '번지', '본번', '아파트명', '도로명']

# %%
# 아래에서 범주형 변수들을 대상으로 레이블인코딩을 진행해 주겠습니다.

# 각 변수에 대한 LabelEncoder를 저장할 딕셔너리
label_encoders = {}

# Implement Label Encoding
for col in tqdm( categorical_columns_v2 ):
    lbl = LabelEncoder()

    # Label-Encoding을 fit
    lbl.fit( df_train[col].astype(str) )
    df_train[col] = lbl.transform(df_train[col].astype(str))
    label_encoders[col] = lbl           # 나중에 후처리를 위해 레이블인코더를 저장해주겠습니다.

    # Test 데이터에만 존재하는 새로 출현한 데이터를 신규 클래스로 추가해줍니다.
    for label in np.unique(df_test[col]):
      if label not in lbl.classes_: # unseen label 데이터인 경우
        lbl.classes_ = np.append(lbl.classes_, label) # 미처리 시 ValueError발생하니 주의하세요!

    df_test[col] = lbl.transform(df_test[col].astype(str))
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  3.02it/s]

# %%
def preprocess_feature_name(feature_name):
  """특수 문자를 제거하고 소문자로 변환합니다."""
  feature_name = feature_name.replace("-", "_")
  feature_name = feature_name.replace(",", "_")
  feature_name = feature_name.replace(".", "_")
  feature_name = feature_name.replace("(", "_")
  feature_name = feature_name.replace(")", "_")
  feature_name = feature_name.lower()
  return feature_name

def apply_preprocessed_feature_names(df_train):
  """데이터 프레임의 feature 이름을 수정합니다."""
  df_train.columns = [preprocess_feature_name(feature) for feature in df_train.columns]
  return df_train

# 데이터 프레임에 적용
df_train = apply_preprocessed_feature_names(df_train.copy())
df_test = apply_preprocessed_feature_names(df_test.copy())

# %%
df_train
# Out:
#          시군구    번지    본번  아파트명   전용면적       계약년월   층  건축년도   도로명  \
# 0          0  4732  1149   328  79.97 2017-12-01   3  1987  6176
# 1          0  4732  1149   328  79.97 2017-12-01   4  1987  6176
# 2          0  4732  1149   328  54.98 2017-12-01   5  1987  6176
# 3          0  4732  1149   328  79.97 2018-01-01   4  1987  6176
# 4          0  4732  1149   328  79.97 2018-01-01   2  1987  6176
# ...      ...   ...   ...   ...    ...        ...  ..   ...   ...
# 1118817  258  3082   822   215  59.94 2007-07-01  11  1998  4816
# 1118818  258  3082   822   215  59.94 2007-08-01  10  1998  4816
# 1118819  258  3082   822   215  84.83 2007-08-01  20  1998  4816
# 1118820  258  3082   822   215  84.83 2007-09-01   8  1998  4816
# 1118821  312   404   101  2177  52.46 2007-01-01   5  1981  4783
#
#          k전용면적별세대현황60이하  ...       거래대금        상장시가총액  kospi_ma5d  \
# 0                  20.0  ...  5484859.0  1.602767e+09    2482.428
# 1                  20.0  ...  4801820.0  1.587460e+09    2460.630
# 2                  20.0  ...  4274352.0  1.605821e+09    2440.374
# 3                  20.0  ...  6019622.0  1.617634e+09    2459.500
# 4                  20.0  ...  6404886.0  1.634778e+09    2488.652
# ...                 ...  ...        ...           ...         ...
# 1118817           171.0  ...  7069439.0  9.458545e+08    1887.768
# 1118818           171.0  ...  6651635.0  9.389746e+08    1861.231
# 1118819           171.0  ...  6233831.0  9.320947e+08    1834.694
# 1118820           171.0  ...  4572966.5  7.990292e+08    1605.746
# 1118821           121.0  ...  2912102.0  6.659636e+08    1376.798
#
#          kospi_ma20d  kospi_ma60d  kospi_ma120d  close_delay120d  \
# 0         2511.16000  2474.657667   2429.492500         2372.640
# 1         2478.32800  2488.367667   2437.279667         2382.560
# 2         2468.15800  2491.502167   2438.526083         2394.480
# 3         2468.86900  2495.173667   2440.168833         2388.350
# 4         2468.42400  2498.354000   2442.897833         2382.100
# ...              ...          ...           ...              ...
# 1118817   1808.68100  1684.931000   1560.047917         1383.210
# 1118818   1809.86350  1758.822500   1623.958208         1403.395
# 1118819   1811.04600  1832.714000   1687.868500         1423.580
# 1118820   1610.28675  1615.687417   1525.040417         1339.355
# 1118821   1409.52750  1398.660833   1362.212333         1255.130
#
#          unempl_rate_total  unempl_male  unempl_female
# 0                      4.4          4.3            4.5
# 1                      4.4          4.3            4.5
# 2                      4.4          4.3            4.5
# 3                      4.4          4.3            4.6
# 4                      4.4          4.3            4.6
# ...                    ...          ...            ...
# 1118817                3.9          4.5            3.0
# 1118818                3.9          4.6            2.8
# 1118819                3.9          4.6            2.8
# 1118820                3.8          4.6            2.7
# 1118821                4.8          5.7            3.5
#
# [1118822 rows x 53 columns]

# %% [markdown]
# ### Holdout Using optuna

# %%
y_train = df_train['target']
X_train = df_train.drop(['target', '계약년월'], axis=1)

# Split the data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=2023)

# %%
import optuna

def objective(trial):
    # Define the hyperparameter search space
    n_estimators = trial.suggest_int('n_estimators', 1000, 5000)
    max_depth = trial.suggest_int('max_depth', 10, 50)
    num_leaves = trial.suggest_int('num_leaves', 100, 1000)
    min_child_samples = trial.suggest_int('min_child_samples', 50, 500)
    feature_fraction = trial.suggest_float('feature_fraction', 0.5, 1.0)
    bagging_fraction = trial.suggest_float('bagging_fraction', 0.5, 1.0)
    lambda_l1 = trial.suggest_float('lambda_l1', 1e-8, 1.0, log=True)  # Increase L1 regularization
    lambda_l2 = trial.suggest_float('lambda_l2', 1e-8, 1.0, log=True)  # Increase L2 regularization

    # Create the LGBMRegressor model with the suggested hyperparameters
    gbm = lgb.LGBMRegressor(n_estimators=n_estimators, max_depth=max_depth, num_leaves=num_leaves,
                            min_child_samples=min_child_samples, feature_fraction=feature_fraction,
                            bagging_fraction=bagging_fraction, lambda_l1=lambda_l1, lambda_l2=lambda_l2, verbosity=-1)

    # Train the model
    gbm.fit(
        X_train, y_train, 
        eval_set=[(X_train, y_train), (X_val, y_val)], 
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=50),
                   lgb.log_evaluation(period=100, show_stdv=True)]
        )
    
    # Compute the validation RMSE
    val_rmse = gbm.best_score_['valid_1']['rmse']
    return val_rmse

def optimize_hyperparameters(n_trials=100, early_stopping=50, log_evaluation=100):
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)

    # Get the best hyperparameters
    best_params = study.best_trial.params

    # Create the final model with the best hyperparameters
    best_model = lgb.LGBMRegressor(**best_params)

    # Train the final model with early stopping and evaluation logging
    best_model.fit(X_train, y_train,
                   eval_set=[(X_train, y_train), (X_val, y_val)],
                   eval_metric='rmse',
                   callbacks=[lgb.early_stopping(stopping_rounds=early_stopping),
                              lgb.log_evaluation(period=log_evaluation, show_stdv=True)])

    return best_model

# %%
best_model = optimize_hyperparameters(n_trials=5)
# Out:
# [I 2024-03-28 06:39:47,039] A new study created in memory with name: no-name-4f9df222-deed-4eb0-bb6c-5116906de528
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse:
# [2400]	training's rmse: 3791.4	training's l2: 1.43747e+07	valid_1's rmse: 6487.82	valid_1's l2: 4.20918e+07
# Did not meet early stopping. Best iteration is:
# [2432]	training's rmse: 3773.78	training's l2: 1.42414e+07	valid_1's rmse: 6485.45	valid_1's l2: 4.20611e+07
# [I 2024-03-28 06:41:21,995] Trial 0 finished with value: 6485.449358486862 and parameters: {'n_estimators': 2433, 'max_depth': 20, 'num_leaves': 358, 'min_child_samples': 323, 'feature_fraction': 0.5759342713633693, 'bagging_fraction': 0.8965251740522262, 'lambda_l1': 0.05785980606010088, 'lambda_l2': 1.0294531525585964e-05}. Best is trial 0 with value: 6485.449358486862.
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7341.18	training's l2: 5.38929e+07	valid_1's rmse: 8291.87	valid_1's l2: 6.8755e+07
# [200]	training's rmse: 6284.54	training's l2: 3.94954e+07	valid_1's rmse: 7512.67	valid_1's l2: 5.64402e+07
# [300]	training's rmse: 5796.53	training's l2: 3.35998e+07	valid_1's rmse: 7219.22	valid_1's l2: 5.21171e+07
# [400]	training's rmse: 5470.05	training's l2: 2.99214e+07	valid_1's rmse: 7036.9	valid_1's l2: 4.95179e+07
# [500]	training's rmse: 5197.57	training's l2: 2.70147e+07	valid_1's rmse: 6910.93	valid_1's l2: 4.77609e+07
# [600]	training's rmse: 4994.16	training's l2: 2.49416e+07	valid_1's rmse: 6822.79	valid_1's l2: 4.65505e+07
# [700]	training's rmse: 4781.42	training's l2: 2.2862e+07	valid_1's rmse: 6736.05	valid_1's l2: 4.53743e+07
# [800]	training's rmse: 4621.99	training's l2: 2.13628e+07	valid_1's rmse: 6687.37	valid_1's l2: 4.47209e+07
# [900]	training's rmse: 4470.1	training's l2: 1.99818e+07	valid_1's rmse: 6632.18	valid_1's l2: 4.39858e+07
# [1000]	training's rmse: 4321.46	training's l2: 1.8675e+07	valid_1's rmse: 6591.95	valid_1's l2: 4.34538e+07
# [1100]	training's rmse: 4196.72	training's l2: 1.76124e+07	valid_1's rmse: 6559.62	valid_1's l2: 4.30286e+07
# [1200]	training's rmse: 4094.43	training's l2: 1.67644e+07	valid_1's rmse: 6536.1	valid_1's l2: 4.27207e+07
# [1300]	training's rmse: 3986.23	training's l2: 1.58901e+07	valid_1's rmse: 6510.92	valid_1's l2: 4.23921e+07
# [1400]	training's rmse: 3897.52	training's l2: 1.51907e+07	valid_1's rmse: 6491.74	valid_1's l2: 4.21427e+07
# [1500]	training's rmse: 3794.33	training's l2: 1.43969e+07	valid_1's rmse: 6471.56	valid_1's l2: 4.18811e+07
# [1600]	training's rmse: 3713.48	training's l2: 1.379e+07	valid_1's rmse: 6460.29	valid_1's l2: 4.17354e+07
# [1700]	training's rmse: 3631.09	training's l2: 1.31848e+07	valid_1's rmse: 6449.38	valid_1's l2: 4.15945e+07
# [1800]	training's rmse: 3543.42	training's l2: 1.25558e+07	valid_1's rmse: 6435.06	valid_1's l2: 4.141e+07
# [1900]	training's rmse: 3459.99	training's l2: 1.19715e+07	valid_1's rmse: 6426.68	valid_1's l2: 4.13022e+07
# [2000]	training's rmse: 3384.47	training's l2: 1.14547e+07	valid_1's rmse: 6415.52	valid_1's l2: 4.1159e+07
# [2100]	training's rmse: 3314.89	training's l2: 1.09885e+07	valid_1's rmse: 6410.78	valid_1's l2: 4.10981e+07
# [2200]	training's rmse: 3249	training's l2: 1.0556e+07	valid_1's rmse: 6404.9	valid_1's l2: 4.10228e+07
# [2300]	training's rmse: 3181.49	training's l2: 1.01219e+07	valid_1's rmse: 6399.79	valid_1's l2: 4.09573e+07
# [2400]	training's rmse: 3118.21	training's l2: 9.7232e+06	valid_1's rmse: 6394.07	valid_1's l2: 4.08841e+07
# [2500]	training's rmse: 3060.02	training's l2: 9.3637e+06	valid_1's rmse: 6387.57	valid_1's l2: 4.08011e+07
# [2600]	training's rmse: 3000.95	training's l2: 9.00568e+06	valid_1's rmse: 6383.57	valid_1's l2: 4.07499e+07
# [2700]	training's rmse: 2952.42	training's l2: 8.7168e+06	valid_1's rmse: 6382.7	valid_1's l2: 4.07388e+07
# [2800]	training's rmse: 2898.44	training's l2: 8.40095e+06	valid_1's rmse: 6380.39	valid_1's l2: 4.07093e+07
# [2900]	training's rmse: 2833.92	training's l2: 8.03111e+06	valid_1's rmse: 6375.66	valid_1's l2: 4.06491e+07
# [3000]	training's rmse: 2788.8	training's l2: 7.77741e+06	valid_1's rmse: 6374.69	valid_1's l2: 4.06366e+07
# [3100]	training's rmse: 2739.07	training's l2: 7.50252e+06	valid_1's rmse: 6370.16	valid_1's l2: 4.05789e+07
# [3200]	training's rmse: 2695.15	training's l2: 7.26385e+06	valid_1's rmse: 6368.09	valid_1's l2: 4.05525e+07
# [3300]	training's rmse: 2649.65	training's l2: 7.02066e+06	valid_1's rmse: 6366.28	valid_1's l2: 4.05295e+07
# [3400]	training's rmse: 2601.28	training's l2: 6.76668e+06	valid_1's rmse: 6365.21	valid_1's l2: 4.05159e+07
# Early stopping, best iteration is:
# [3444]	training's rmse: 2579.56	training's l2: 6.65414e+06	valid_1's rmse: 6364.59	valid_1's l2: 4.05081e+07
# [I 2024-03-28 06:43:13,717] Trial 1 finished with value: 6364.59395661742 and parameters: {'n_estimators': 4356, 'max_depth': 13, 'num_leaves': 755, 'min_child_samples': 122, 'feature_fraction': 0.8954270282670834, 'bagging_fraction': 0.8697700254324433, 'lambda_l1': 0.0008132011408533237, 'lambda_l2': 2.8166205283122015e-05}. Best is trial 1 with value: 6364.59395661742.
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7784.06	training's l2: 6.05916e+07	valid_1's rmse: 8597.06	valid_1's l2: 7.39094e+07
# [200]	training's rmse: 6593.41	training's l2: 4.34731e+07	valid_1's rmse: 7681.2	valid_1's l2: 5.90008e+07
# [300]	training's rmse: 6026	training's l2: 3.63127e+07	valid_1's rmse: 7339.24	valid_1's l2: 5.38645e+07
# [400]	training's rmse: 5639.71	training's l2: 3.18063e+07	valid_1's rmse: 7148.56	valid_1's l2: 5.11019e+07
# [500]	training's rmse: 5346.22	training's l2: 2.85821e+07	valid_1's rmse: 7029.74	valid_1's l2: 4.94172e+07
# [2800]	training's rmse: 3051.73	training's l2: 9.31305e+06	valid_1's rmse: 6518.53	valid_1's l2: 4.24912e+07
# [2900]	training's rmse: 2996.83	training's l2: 8.98096e+06	valid_1's rmse: 6517.44	valid_1's l2: 4.2477e+07
# [3000]	training's rmse: 2935.05	training's l2: 8.61454e+06	valid_1's rmse: 6515.04	valid_1's l2: 4.24457e+07
# [3100]	training's rmse: 2882.3	training's l2: 8.30764e+06	valid_1's rmse: 6512.49	valid_1's l2: 4.24125e+07
# [3200]	training's rmse: 2827.71	training's l2: 7.99594e+06	valid_1's rmse: 6511.15	valid_1's l2: 4.23951e+07
# Early stopping, best iteration is:
# [3162]	training's rmse: 2848.48	training's l2: 8.11386e+06	valid_1's rmse: 6510.78	valid_1's l2: 4.23902e+07
# [I 2024-03-28 06:47:56,560] Trial 3 finished with value: 6510.777502230608 and parameters: {'n_estimators': 3435, 'max_depth': 27, 'num_leaves': 667, 'min_child_samples': 313, 'feature_fraction': 0.8268430365901533, 'bagging_fraction': 0.9194302441841035, 'lambda_l1': 0.1281863344746334, 'lambda_l2': 0.00933909430747634}. Best is trial 1 with value: 6364.59395661742.
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 8519.74	training's l2: 7.2586e+07	valid_1's rmse: 9172.11	valid_1's l2: 8.41276e+07
# [200]	training's rmse: 7328.38	training's l2: 5.37052e+07	valid_1's rmse: 8176.03	valid_1's l2: 6.68475e+07
# [300]	training's rmse: 6778.44	training's l2: 4.59472e+07	valid_1's rmse: 7777.03	valid_1's l2: 6.04821e+07
# [400]	training's rmse: 6406.73	training's l2: 4.10462e+07	valid_1's rmse: 7538.44	valid_1's l2: 5.68281e+07
# [500]	training's rmse: 6130.27	training's l2: 3.75802e+07	valid_1's rmse: 7381	valid_1's l2: 5.44791e+07
# [600]	training's rmse: 5907.49	training's l2: 3.48984e+07	valid_1's rmse: 7265.52	valid_1's l2: 5.27878e+07
# [700]	training's rmse: 5730.45	training's l2: 3.2838e+07	valid_1's rmse: 7182.08	valid_1's l2: 5.15823e+07
# [800]	training's rmse: 5564.33	training's l2: 3.09618e+07	valid_1's rmse: 7105	valid_1's l2: 5.0481e+07
# [900]	training's rmse: 5416.97	training's l2: 2.93436e+07	valid_1's rmse: 7042.03	valid_1's l2: 4.95902e+07
# [1000]	training's rmse: 5282.53	training's l2: 2.79051e+07	valid_1's rmse: 6986.15	valid_1's l2: 4.88063e+07
# [1100]	training's rmse: 5164.17	training's l2: 2.66687e+07	valid_1's rmse: 6940.13	valid_1's l2: 4.81655e+07
# [1200]	training's rmse: 5051.12	training's l2: 2.55138e+07	valid_1's rmse: 6899.58	valid_1's l2: 4.76042e+07
# [1300]	training's rmse: 4953.89	training's l2: 2.45411e+07	valid_1's rmse: 6869.54	valid_1's l2: 4.71906e+07
# [1400]	training's rmse: 4851.8	training's l2: 2.35399e+07	valid_1's rmse: 6836.21	valid_1's l2: 4.67338e+07
# [1500]	training's rmse: 4766.59	training's l2: 2.27204e+07	valid_1's rmse: 6813.52	valid_1's l2: 4.6424e+07
# [1600]	training's rmse: 4687.19	training's l2: 2.19697e+07	valid_1's rmse: 6792.99	valid_1's l2: 4.61447e+07
# [1700]	training's rmse: 4607.2	training's l2: 2.12263e+07	valid_1's rmse: 6772.38	valid_1's l2: 4.58651e+07
# [1800]	training's rmse: 4533.2	training's l2: 2.05499e+07	valid_1's rmse: 6756.07	valid_1's l2: 4.56444e+07
# [1900]	training's rmse: 4463.88	training's l2: 1.99263e+07	valid_1's rmse: 6740.1	valid_1's l2: 4.5429e+07
# [2000]	training's rmse: 4394.16	training's l2: 1.93087e+07	valid_1's rmse: 6722.49	valid_1's l2: 4.51919e+07
# [2100]	training's rmse: 4328.22	training's l2: 1.87335e+07	valid_1's rmse: 6709.89	valid_1's l2: 4.50226e+07
# [2200]	training's rmse: 4264.33	training's l2: 1.81845e+07	valid_1's rmse: 6696.61	valid_1's l2: 4.48445e+07
# [2300]	training's rmse: 4209.25	training's l2: 1.77178e+07	valid_1's rmse: 6688.03	valid_1's l2: 4.47298e+07
# [2400]	training's rmse: 4155.42	training's l2: 1.72675e+07	valid_1's rmse: 6679.2	valid_1's l2: 4.46117e+07
# [2500]	training's rmse: 4097.67	training's l2: 1.67909e+07	valid_1's rmse: 6671.98	valid_1's l2: 4.45153e+07
# [2600]	training's rmse: 4044.97	training's l2: 1.63618e+07	valid_1's rmse: 6664.26	valid_1's l2: 4.44124e+07
# [2700]	training's rmse: 3995.63	training's l2: 1.5965e+07	valid_1's rmse: 6657.05	valid_1's l2: 4.43164e+07
# [2800]	training's rmse: 3943.53	training's l2: 1.55514e+07	valid_1's rmse: 6650.5	valid_1's l2: 4.42292e+07
# [2900]	training's rmse: 3893.62	training's l2: 1.51603e+07	valid_1's rmse: 6643.99	valid_1's l2: 4.41426e+07
# [3000]	training's rmse: 3839.32	training's l2: 1.47404e+07	valid_1's rmse: 6637.2	valid_1's l2: 4.40524e+07
# Did not meet early stopping. Best iteration is:
# [3006]	training's rmse: 3836.61	training's l2: 1.47196e+07	valid_1's rmse: 6636.41	valid_1's l2: 4.40419e+07
# [I 2024-03-28 06:50:10,612] Trial 4 finished with value: 6636.410582997472 and parameters: {'n_estimators': 3007, 'max_depth': 30, 'num_leaves': 491, 'min_child_samples': 486, 'feature_fraction': 0.9469740532746139, 'bagging_fraction': 0.56747212391, 'lambda_l1': 1.587831839352549e-08, 'lambda_l2': 0.21814311158632324}. Best is trial 1 with value: 6364.59395661742.
# [LightGBM] [Warning] feature_fraction is set=0.8954270282670834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8954270282670834
# [LightGBM] [Warning] lambda_l2 is set=2.8166205283122015e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.8166205283122015e-05
# [LightGBM] [Warning] lambda_l1 is set=0.0008132011408533237, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0008132011408533237
# [LightGBM] [Warning] bagging_fraction is set=0.8697700254324433, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8697700254324433
# [LightGBM] [Warning] feature_fraction is set=0.8954270282670834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8954270282670834
# [LightGBM] [Warning] lambda_l2 is set=2.8166205283122015e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.8166205283122015e-05
# [LightGBM] [Warning] lambda_l1 is set=0.0008132011408533237, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0008132011408533237
# [LightGBM] [Warning] bagging_fraction is set=0.8697700254324433, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8697700254324433
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5838
# [LightGBM] [Info] Number of data points in the train set: 895057, number of used features: 51
# [LightGBM] [Warning] feature_fraction is set=0.8954270282670834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8954270282670834
# [LightGBM] [Warning] lambda_l2 is set=2.8166205283122015e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.8166205283122015e-05
# [LightGBM] [Warning] lambda_l1 is set=0.0008132011408533237, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0008132011408533237
# [LightGBM] [Warning] bagging_fraction is set=0.8697700254324433, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8697700254324433
# [LightGBM] [Info] Start training from score 58000.483999
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's rmse: 7341.18	training's l2: 5.38929e+07	valid_1's rmse: 8291.87	valid_1's l2: 6.8755e+07
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	training's rmse: 6284.54	training's l2: 3.94954e+07	valid_1's rmse: 7512.67	valid_1's l2: 5.64402e+07
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's rmse: 5796.53	training's l2: 3.35998e+07	valid_1's rmse: 7219.22	valid_1's l2: 5.21171e+07
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 5470.05	training's l2: 2.99214e+07	valid_1's rmse: 7036.9	valid_1's l2: 4.95179e+07
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3300]	training's rmse: 2649.65	training's l2: 7.02066e+06	valid_1's rmse: 6366.28	valid_1's l2: 4.05295e+07
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3400]	training's rmse: 2601.28	training's l2: 6.76668e+06	valid_1's rmse: 6365.21	valid_1's l2: 4.05159e+07
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [3444]	training's rmse: 2579.56	training's l2: 6.65414e+06	valid_1's rmse: 6364.59	valid_1's l2: 4.05081e+07

# %%
best_model.best_score_
# Out:
# defaultdict(collections.OrderedDict,
#             {'training': OrderedDict([('rmse', 2579.562193534013),
#                           ('l2', 6654141.110310011)]),
#              'valid_1': OrderedDict([('rmse', 6364.593956615157),
#                           ('l2', 40508056.23258218)])})

# %%
X_test = df_test.drop(['target', '계약년월'], axis=1)
real_test_pred = best_model.predict(X_test)
preds_df = pd.DataFrame(real_test_pred.astype(int), columns=["target"])
preds_df.to_csv('holdout_optuna_output.csv', index=False)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8954270282670834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8954270282670834
# [LightGBM] [Warning] lambda_l2 is set=2.8166205283122015e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.8166205283122015e-05
# [LightGBM] [Warning] lambda_l1 is set=0.0008132011408533237, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0008132011408533237
# [LightGBM] [Warning] bagging_fraction is set=0.8697700254324433, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8697700254324433

# %%
preds_df.median()
# Out:
# target    92986.5
# dtype: float64

# %% [markdown]
# ### holdout

# %%
def holdout_lgb(X, y, test=pd.DataFrame, test_size=0.2, random_state=2023 ,gbm = lgb.LGBMRegressor(n_estimators=1000), early_stopping=10, log_evaluation=10):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size, random_state=random_state)
    gbm.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_val, y_val)],
            eval_metric='rmse',
            callbacks=[lgb.early_stopping(stopping_rounds=early_stopping),
                   lgb.log_evaluation(period=log_evaluation, show_stdv=True)])
    
    if not test.empty:
        real_test_pred = gbm.predict(test)
        preds_df = pd.DataFrame(real_test_pred.astype(int), columns=["target"])
        preds_df.to_csv('holdout_output.csv', index=False)

        # return preds_df

    return gbm

# %%
y_train = df_train['target']
X_train = df_train.drop(['target', '계약년월'], axis=1)
X_test = df_test.drop(['target', '계약년월'], axis=1)
gbm = lgb.LGBMRegressor(n_estimators=2000, max_depth=20, num_leaves=100,
                            min_child_samples=60, feature_fraction=0.8,
                            bagging_fraction=0.8)
gbm = holdout_lgb(X_train,y_train, test=X_test, gbm=gbm)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0
# [1930]	training's rmse: 4264.73	training's l2: 1.81879e+07	valid_1's rmse: 6386.54	valid_1's l2: 4.07879e+07
# [1940]	training's rmse: 4257.69	training's l2: 1.81279e+07	valid_1's rmse: 6385.15	valid_1's l2: 4.07702e+07
# [1950]	training's rmse: 4249.53	training's l2: 1.80585e+07	valid_1's rmse: 6381.8	valid_1's l2: 4.07273e+07
# [1960]	training's rmse: 4242.01	training's l2: 1.79946e+07	valid_1's rmse: 6378.52	valid_1's l2: 4.06856e+07
# [1970]	training's rmse: 4232.94	training's l2: 1.79177e+07	valid_1's rmse: 6376.02	valid_1's l2: 4.06536e+07
# [1980]	training's rmse: 4224.83	training's l2: 1.78491e+07	valid_1's rmse: 6373.66	valid_1's l2: 4.06235e+07
# [1990]	training's rmse: 4217.42	training's l2: 1.77867e+07	valid_1's rmse: 6370.61	valid_1's l2: 4.05846e+07
# [2000]	training's rmse: 4210.75	training's l2: 1.77304e+07	valid_1's rmse: 6369.41	valid_1's l2: 4.05693e+07
# Did not meet early stopping. Best iteration is:
# [1998]	training's rmse: 4212.37	training's l2: 1.77441e+07	valid_1's rmse: 6368.89	valid_1's l2: 4.05628e+07
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8

# %%
gbm.best_score_['valid_1']['rmse']
# Out:
# 6368.889805103728

# %% [markdown]
# ## 데이터 분리

# %%
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, GroupKFold, TimeSeriesSplit

# %% [markdown]
# ### K-Fold

# %%
def k_fold_lgb(X, y, test=pd.DataFrame, n_splits=5, gbm=lgb.LGBMRegressor(n_estimators=1000), early_stopping=10, log_evaluation=10):
    # Kfold 함수를 선언합니다.
    kf = KFold(n_splits=n_splits)
    # 학습 데이터를 Kfold로 나눕니다.
    train_folds = kf.split(X, y)

    fold_save_files = []

    for fold_idx, (train_idx, valid_idx) in enumerate(train_folds):
        print(f"--------{fold_idx}번째 fold의 학습을 시작합니다.--------")

        # index를 통해 fold의 학습세트를 가져옵니다.
        X_train_fold = X.iloc[train_idx, :]
        Y_train_fold = y[train_idx]

        # index를 통해 fold의 평가세트를 가져옵니다.
        X_valid_fold = X.iloc[valid_idx, :]
        Y_valid_fold = y[valid_idx]

        # fold의 데이터로 학습을 진행합니다.
        gbm.fit(X_train_fold, Y_train_fold,                                               # 학습 데이터를 입력합니다.
            eval_set=[(X_train_fold, Y_train_fold), (X_valid_fold, Y_valid_fold)], # 평가셋을 지정합니다.
            eval_metric ='rmse',                                                               # 평가과정에서 사용할 평가함수를 지정합니다.
            callbacks=[lgb.early_stopping(stopping_rounds=early_stopping),                                  # 10번의 성능향상이 없을 경우, 학습을 멈춥니다.
                    lgb.log_evaluation(period=log_evaluation, show_stdv=True)]                           # 매 iteration마다 학습결과를 출력합니다.
        )

        # 각 fold별 학습한 모델을 저장합니다.
        file_name = f"kfold{fold_idx}_gbm.pkl"
        joblib.dump(gbm, file_name)
        print(f"--------{fold_idx}번째 fold는 {file_name}에 저장되었습니다.--------\n\n")
        fold_save_files.append(file_name)

    # 저장한 학습모델들을 불러와, Testset에 대한 추론을 진행합니다.
    # 각 fold의 예측결과를 평균을 취하는 방식으로 진행합니다.
    if not test.empty:
        total_predicts = np.zeros(len(X_test))

        for file_name in fold_save_files:
            gbm_trained = joblib.load(file_name)
            fold_predicts = gbm_trained.predict(X_test)

            total_predicts += fold_predicts / len(fold_save_files)
        
        # 앞서 예측한 예측값들을 저장합니다.
        preds_df = pd.DataFrame(total_predicts.astype(int), columns=["target"])
        preds_df.to_csv('k-fold_output.csv', index=False)

        return preds_df

# %%
k_fold_lgb(X_train, y_train, X_test)
# Out:
# --------0번째 fold의 학습을 시작합니다.--------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051924 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5815
# [LightGBM] [Info] Number of data points in the train set: 895057, number of used features: 51
# [LightGBM] [Info] Start training from score 57132.425269
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 25736.7	training's l2: 6.62376e+08	valid_1's rmse: 26119	valid_1's l2: 6.82204e+08
# [20]	training's rmse: 19137.5	training's l2: 3.66245e+08	valid_1's rmse: 22297.8	valid_1's l2: 4.97192e+08
# [30]	training's rmse: 16350.4	training's l2: 2.67337e+08	valid_1's rmse: 21327.7	valid_1's l2: 4.54872e+08
# [40]	training's rmse: 14931.9	training's l2: 2.22962e+08	valid_1's rmse: 20775.8	valid_1's l2: 4.31632e+08
# [50]	training's rmse: 14002.5	training's l2: 1.9607e+08	valid_1's rmse: 20339.9	valid_1's l2: 4.1371e+08
# [60]	training's rmse: 13339.4	training's l2: 1.77939e+08	valid_1's rmse: 20207.5	valid_1's l2: 4.08343e+08
# [70]	training's rmse: 12856.6	training's l2: 1.65291e+08	valid_1's rmse: 19977.8	valid_1's l2: 3.99114e+08
# [80]	training's rmse: 12480.9	training's l2: 1.55772e+08	valid_1's rmse: 19860	valid_1's l2: 3.94418e+08
# [90]	training's rmse: 12142.8	training's l2: 1.47448e+08	valid_1's rmse: 19652.6	valid_1's l2: 3.86225e+08
# [100]	training's rmse: 11872.1	training's l2: 1.40948e+08	valid_1's rmse: 19488.1	valid_1's l2: 3.79787e+08
# [110]	training's rmse: 11615.4	training's l2: 1.34917e+08	valid_1's rmse: 19230	valid_1's l2: 3.69795e+08
# [120]	training's rmse: 11388.9	training's l2: 1.29706e+08	valid_1's rmse: 19084.9	valid_1's l2: 3.64233e+08
# [130]	training's rmse: 11195.7	training's l2: 1.25345e+08	valid_1's rmse: 18878.9	valid_1's l2: 3.56414e+08
# [140]	training's rmse: 11020.3	training's l2: 1.21446e+08	valid_1's rmse: 18782.4	valid_1's l2: 3.5278e+08
# [150]	training's rmse: 10830.9	training's l2: 1.17309e+08	valid_1's rmse: 18664.3	valid_1's l2: 3.48357e+08
# [160]	training's rmse: 10674.4	training's l2: 1.13944e+08	valid_1's rmse: 18571.1	valid_1's l2: 3.44885e+08
# [170]	training's rmse: 10512.4	training's l2: 1.1051e+08	valid_1's rmse: 18454.1	valid_1's l2: 3.40555e+08
# [180]	training's rmse: 10366.9	training's l2: 1.07473e+08	valid_1's rmse: 18414.3	valid_1's l2: 3.39087e+08
# [190]	training's rmse: 10228.4	training's l2: 1.04621e+08	valid_1's rmse: 18317.6	valid_1's l2: 3.35533e+08
# [200]	training's rmse: 10092.4	training's l2: 1.01857e+08	valid_1's rmse: 18237.4	valid_1's l2: 3.32604e+08
# [210]	training's rmse: 9966.53	training's l2: 9.93317e+07	valid_1's rmse: 18178.1	valid_1's l2: 3.30443e+08
# [220]	training's rmse: 9850.66	training's l2: 9.70355e+07	valid_1's rmse: 18084.9	valid_1's l2: 3.27065e+08
# [230]	training's rmse: 9738.01	training's l2: 9.48288e+07	valid_1's rmse: 18088.9	valid_1's l2: 3.2721e+08
# Early stopping, best iteration is:
# [227]	training's rmse: 9774.79	training's l2: 9.55465e+07	valid_1's rmse: 18043.7	valid_1's l2: 3.25577e+08
# --------0번째 fold는 kfold0_gbm.pkl에 저장되었습니다.--------
#
#
# --------1번째 fold의 학습을 시작합니다.--------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5807
# [LightGBM] [Info] Number of data points in the train set: 895057, number of used features: 51
# [LightGBM] [Info] Start training from score 50367.934637
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 20360.2	training's l2: 4.14538e+08	valid_1's rmse: 54204.5	valid_1's l2: 2.93813e+09
# [20]	training's rmse: 15080.3	training's l2: 2.27415e+08	valid_1's rmse: 45567	valid_1's l2: 2.07635e+09
# [30]	training's rmse: 12835	training's l2: 1.64738e+08	valid_1's rmse: 41728.9	valid_1's l2: 1.7413e+09
# [40]	training's rmse: 11732.6	training's l2: 1.37653e+08	valid_1's rmse: 39463.3	valid_1's l2: 1.55735e+09
# [50]	training's rmse: 11034.5	training's l2: 1.21759e+08	valid_1's rmse: 38119.6	valid_1's l2: 1.4531e+09
# [60]	training's rmse: 10518.7	training's l2: 1.10643e+08	valid_1's rmse: 37036.3	valid_1's l2: 1.37169e+09
# [70]	training's rmse: 10150.4	training's l2: 1.03031e+08	valid_1's rmse: 36514.3	valid_1's l2: 1.33329e+09
# [80]	training's rmse: 9857.83	training's l2: 9.71768e+07	valid_1's rmse: 36045.4	valid_1's l2: 1.29927e+09
# [90]	training's rmse: 9611.79	training's l2: 9.23865e+07	valid_1's rmse: 35614.1	valid_1's l2: 1.26836e+09
# [100]	training's rmse: 9384.8	training's l2: 8.80744e+07	valid_1's rmse: 35249.3	valid_1's l2: 1.24251e+09
# [110]	training's rmse: 9183.25	training's l2: 8.43321e+07	valid_1's rmse: 35074.7	valid_1's l2: 1.23023e+09
# [120]	training's rmse: 8999.37	training's l2: 8.09887e+07	valid_1's rmse: 34847.1	valid_1's l2: 1.21432e+09
# [130]	training's rmse: 8821.98	training's l2: 7.78273e+07	valid_1's rmse: 34264	valid_1's l2: 1.17402e+09
# [140]	training's rmse: 8678.42	training's l2: 7.5315e+07	valid_1's rmse: 34034	valid_1's l2: 1.15831e+09
# [150]	training's rmse: 8545.56	training's l2: 7.30266e+07	valid_1's rmse: 33881.5	valid_1's l2: 1.14795e+09
# [160]	training's rmse: 8437.45	training's l2: 7.11905e+07	valid_1's rmse: 33737.3	valid_1's l2: 1.13821e+09
# [170]	training's rmse: 8300.34	training's l2: 6.88957e+07	valid_1's rmse: 33628.7	valid_1's l2: 1.13089e+09
# [180]	training's rmse: 8199.65	training's l2: 6.72343e+07	valid_1's rmse: 33156	valid_1's l2: 1.09932e+09
# [430]	training's rmse: 6684.82	training's l2: 4.46869e+07	valid_1's rmse: 31045.4	valid_1's l2: 9.63819e+08
# [440]	training's rmse: 6653.04	training's l2: 4.4263e+07	valid_1's rmse: 30969.7	valid_1's l2: 9.59124e+08
# [450]	training's rmse: 6619.24	training's l2: 4.38143e+07	valid_1's rmse: 30913.8	valid_1's l2: 9.55664e+08
# [460]	training's rmse: 6581.21	training's l2: 4.33124e+07	valid_1's rmse: 30885.5	valid_1's l2: 9.53917e+08
# [470]	training's rmse: 6546.53	training's l2: 4.28571e+07	valid_1's rmse: 30819.1	valid_1's l2: 9.49814e+08
# [480]	training's rmse: 6510.88	training's l2: 4.23915e+07	valid_1's rmse: 30804.2	valid_1's l2: 9.48898e+08
# [490]	training's rmse: 6477.49	training's l2: 4.19579e+07	valid_1's rmse: 30754.3	valid_1's l2: 9.4583e+08
# [500]	training's rmse: 6444.98	training's l2: 4.15378e+07	valid_1's rmse: 30703.5	valid_1's l2: 9.42704e+08
# [510]	training's rmse: 6415.75	training's l2: 4.11618e+07	valid_1's rmse: 30660.1	valid_1's l2: 9.40039e+08
# [520]	training's rmse: 6382.93	training's l2: 4.07418e+07	valid_1's rmse: 30623.8	valid_1's l2: 9.37816e+08
# [530]	training's rmse: 6355.18	training's l2: 4.03883e+07	valid_1's rmse: 30606.2	valid_1's l2: 9.36737e+08
# [540]	training's rmse: 6327.46	training's l2: 4.00368e+07	valid_1's rmse: 30587.1	valid_1's l2: 9.35571e+08
# [550]	training's rmse: 6300.05	training's l2: 3.96907e+07	valid_1's rmse: 30570	valid_1's l2: 9.34524e+08
# [560]	training's rmse: 6271.14	training's l2: 3.93272e+07	valid_1's rmse: 30513.5	valid_1's l2: 9.31072e+08
# [570]	training's rmse: 6240.37	training's l2: 3.89422e+07	valid_1's rmse: 30508.1	valid_1's l2: 9.30744e+08
# [580]	training's rmse: 6214.65	training's l2: 3.86219e+07	valid_1's rmse: 30484.4	valid_1's l2: 9.29301e+08
# [590]	training's rmse: 6191.93	training's l2: 3.83399e+07	valid_1's rmse: 30418.4	valid_1's l2: 9.25278e+08
# [600]	training's rmse: 6167.24	training's l2: 3.80349e+07	valid_1's rmse: 30414.2	valid_1's l2: 9.25025e+08
# [610]	training's rmse: 6139.04	training's l2: 3.76878e+07	valid_1's rmse: 30320	valid_1's l2: 9.19302e+08
# [620]	training's rmse: 6114.55	training's l2: 3.73878e+07	valid_1's rmse: 30356.5	valid_1's l2: 9.21515e+08
# Early stopping, best iteration is:
# [612]	training's rmse: 6134.37	training's l2: 3.76306e+07	valid_1's rmse: 30318.3	valid_1's l2: 9.19199e+08
# --------1번째 fold는 kfold1_gbm.pkl에 저장되었습니다.--------
#
#
# --------2번째 fold의 학습을 시작합니다.--------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.040276 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5833
# [LightGBM] [Info] Number of data points in the train set: 895058, number of used features: 51
# [LightGBM] [Info] Start training from score 59038.643938
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse:
# [270]	training's rmse: 9839.54	training's l2: 9.68166e+07	valid_1's rmse: 10221.4	valid_1's l2: 1.04478e+08
# [280]	training's rmse: 9758.36	training's l2: 9.52255e+07	valid_1's rmse: 10189.2	valid_1's l2: 1.0382e+08
# [290]	training's rmse: 9667.85	training's l2: 9.34673e+07	valid_1's rmse: 10156.8	valid_1's l2: 1.03161e+08
# [300]	training's rmse: 9596.05	training's l2: 9.20842e+07	valid_1's rmse: 10091.2	valid_1's l2: 1.01833e+08
# [310]	training's rmse: 9520.95	training's l2: 9.06484e+07	valid_1's rmse: 9985.66	valid_1's l2: 9.97134e+07
# [320]	training's rmse: 9452.14	training's l2: 8.9343e+07	valid_1's rmse: 9888.74	valid_1's l2: 9.77872e+07
# [330]	training's rmse: 9381.77	training's l2: 8.80175e+07	valid_1's rmse: 9880.96	valid_1's l2: 9.76334e+07
# [340]	training's rmse: 9318.13	training's l2: 8.68276e+07	valid_1's rmse: 9831.05	valid_1's l2: 9.66495e+07
# [350]	training's rmse: 9254.66	training's l2: 8.56488e+07	valid_1's rmse: 9775.17	valid_1's l2: 9.5554e+07
# [360]	training's rmse: 9177.82	training's l2: 8.42324e+07	valid_1's rmse: 9739.47	valid_1's l2: 9.48572e+07
# [370]	training's rmse: 9123.58	training's l2: 8.32396e+07	valid_1's rmse: 9715.65	valid_1's l2: 9.43938e+07
# [380]	training's rmse: 9054.03	training's l2: 8.19755e+07	valid_1's rmse: 9689.74	valid_1's l2: 9.38911e+07
# [390]	training's rmse: 8999.77	training's l2: 8.09959e+07	valid_1's rmse: 9656.08	valid_1's l2: 9.324e+07
# [400]	training's rmse: 8948.58	training's l2: 8.0077e+07	valid_1's rmse: 9605.95	valid_1's l2: 9.22743e+07
# [410]	training's rmse: 8891.14	training's l2: 7.90524e+07	valid_1's rmse: 9545.76	valid_1's l2: 9.11215e+07
# [420]	training's rmse: 8836.67	training's l2: 7.80867e+07	valid_1's rmse: 9521.67	valid_1's l2: 9.06622e+07
# [430]	training's rmse: 8790.26	training's l2: 7.72687e+07	valid_1's rmse: 9498.88	valid_1's l2: 9.02287e+07
# [440]	training's rmse: 8740.86	training's l2: 7.64026e+07	valid_1's rmse: 9477.55	valid_1's l2: 8.98239e+07
# [450]	training's rmse: 8691.72	training's l2: 7.55461e+07	valid_1's rmse: 9458.14	valid_1's l2: 8.94564e+07
# [460]	training's rmse: 8641.48	training's l2: 7.46753e+07	valid_1's rmse: 9423.3	valid_1's l2: 8.87986e+07
# [470]	training's rmse: 8604.25	training's l2: 7.40332e+07	valid_1's rmse: 9344.9	valid_1's l2: 8.73271e+07
# [480]	training's rmse: 8568.36	training's l2: 7.34167e+07	valid_1's rmse: 9328.03	valid_1's l2: 8.70122e+07
# [490]	training's rmse: 8527.98	training's l2: 7.27264e+07	valid_1's rmse: 9309.37	valid_1's l2: 8.66643e+07
# [500]	training's rmse: 8475.56	training's l2: 7.18351e+07	valid_1's rmse: 9293.58	valid_1's l2: 8.63706e+07
# [510]	training's rmse: 8445.21	training's l2: 7.13216e+07	valid_1's rmse: 9291.74	valid_1's l2: 8.63365e+07
# [520]	training's rmse: 8403.21	training's l2: 7.06139e+07	valid_1's rmse: 9274.83	valid_1's l2: 8.60225e+07
# [530]	training's rmse: 8358.6	training's l2: 6.98661e+07	valid_1's rmse: 9248.82	valid_1's l2: 8.55407e+07
# [540]	training's rmse: 8325.95	training's l2: 6.93214e+07	valid_1's rmse: 9237.13	valid_1's l2: 8.53245e+07
# [550]	training's rmse: 8288.23	training's l2: 6.86948e+07	valid_1's rmse: 9222.3	valid_1's l2: 8.50508e+07
# [560]	training's rmse: 8240.6	training's l2: 6.79075e+07	valid_1's rmse: 9209.24	valid_1's l2: 8.481e+07
# [570]	training's rmse: 8208.54	training's l2: 6.73801e+07	valid_1's rmse: 9184.59	valid_1's l2: 8.43567e+07
# [580]	training's rmse: 8173.97	training's l2: 6.68137e+07	valid_1's rmse: 9157.28	valid_1's l2: 8.38558e+07
# [590]	training's rmse: 8135.07	training's l2: 6.61794e+07	valid_1's rmse: 9130.89	valid_1's l2: 8.33731e+07
# [600]	training's rmse: 8108.16	training's l2: 6.57423e+07	valid_1's rmse: 9080.21	valid_1's l2: 8.24502e+07
# [610]	training's rmse: 8074.84	training's l2: 6.52031e+07	valid_1's rmse: 9069.18	valid_1's l2: 8.22501e+07
# [620]	training's rmse: 8040.7	training's l2: 6.46528e+07	valid_1's rmse: 9061.25	valid_1's l2: 8.21062e+07
# [630]	training's rmse: 8006.79	training's l2: 6.41087e+07	valid_1's rmse: 9051.3	valid_1's l2: 8.1926e+07
# [640]	training's rmse: 7975.51	training's l2: 6.36088e+07	valid_1's rmse: 9043.96	valid_1's l2: 8.17931e+07
# [650]	training's rmse: 7944.52	training's l2: 6.31154e+07	valid_1's rmse: 9030.19	valid_1's l2: 8.15443e+07
# [660]	training's rmse: 7912.83	training's l2: 6.26129e+07	valid_1's rmse: 9014.35	valid_1's l2: 8.12586e+07
# [670]	training's rmse: 7881.28	training's l2: 6.21146e+07	valid_1's rmse: 9001.12	valid_1's l2: 8.10202e+07
# [680]	training's rmse: 7849.68	training's l2: 6.16175e+07	valid_1's rmse: 8985.39	valid_1's l2: 8.07371e+07
# [690]	training's rmse: 7820.59	training's l2: 6.11616e+07	valid_1's rmse: 8974.72	valid_1's l2: 8.05457e+07
# [700]	training's rmse: 7797.78	training's l2: 6.08053e+07	valid_1's rmse: 8967.74	valid_1's l2: 8.04204e+07
# [710]	training's rmse: 7773.59	training's l2: 6.04287e+07	valid_1's rmse: 8962.15	valid_1's l2: 8.03201e+07
# [720]	training's rmse: 7746.22	training's l2: 6.00039e+07	valid_1's rmse: 8945.63	valid_1's l2: 8.00243e+07
# [730]	training's rmse: 7716.13	training's l2: 5.95387e+07	valid_1's rmse: 8935.12	valid_1's l2: 7.98364e+07
# [740]	training's rmse: 7692.33	training's l2: 5.91719e+07	valid_1's rmse: 8914.6	valid_1's l2: 7.94701e+07
# [750]	training's rmse: 7669.06	training's l2: 5.88144e+07	valid_1's rmse: 8909.52	valid_1's l2: 7.93795e+07
# [760]	training's rmse: 7647.8	training's l2: 5.84889e+07	valid_1's rmse: 8902.74	valid_1's l2: 7.92588e+07
# [770]	training's rmse: 7618.86	training's l2: 5.8047e+07	valid_1's rmse: 8882.43	valid_1's l2: 7.88976e+07
# [780]	training's rmse: 7598.04	training's l2: 5.77303e+07	valid_1's rmse: 8877.76	valid_1's l2: 7.88147e+07
# [790]	training's rmse: 7574.15	training's l2: 5.73678e+07	valid_1's rmse: 8865.19	valid_1's l2: 7.85915e+07
# [800]	training's rmse: 7540.93	training's l2: 5.68656e+07	valid_1's rmse: 8850.6	valid_1's l2: 7.83331e+07
# [810]	training's rmse: 7521.36	training's l2: 5.65709e+07	valid_1's rmse: 8850.48	valid_1's l2: 7.83311e+07
# Early stopping, best iteration is:
# [805]	training's rmse: 7530.37	training's l2: 5.67065e+07	valid_1's rmse: 8846.2	valid_1's l2: 7.82553e+07
# --------2번째 fold는 kfold2_gbm.pkl에 저장되었습니다.--------
#
#
# --------3번째 fold의 학습을 시작합니다.--------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051736 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5841
# [LightGBM] [Info] Number of data points in the train set: 895058, number of used features: 51
# [LightGBM] [Info] Start training from score 61242.900842
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 27533.4	training's l2: 7.5809e+08	valid_1's rmse: 17149.5	valid_1's l2: 2.94107e+08
# [20]	training's rmse: 20543	training's l2: 4.22014e+08	valid_1's rmse: 13113.5	valid_1's l2: 1.71965e+08
# [30]	training's rmse: 17498.3	training's l2: 3.06189e+08	valid_1's rmse: 11484	valid_1's l2: 1.31882e+08
# [40]	training's rmse: 15980.8	training's l2: 2.55385e+08	valid_1's rmse: 10869.8	valid_1's l2: 1.18153e+08
# [50]	training's rmse: 15001.5	training's l2: 2.25044e+08	valid_1's rmse: 10411.8	valid_1's l2: 1.08405e+08
# [60]	training's rmse: 14324.1	training's l2: 2.0518e+08	valid_1's rmse: 10144.4	valid_1's l2: 1.02908e+08
# [70]	training's rmse: 13781.3	training's l2: 1.89924e+08	valid_1's rmse: 9897.63	valid_1's l2: 9.7963e+07
# [80]	training's rmse: 13333.4	training's l2: 1.77778e+08	valid_1's rmse: 9591.36	valid_1's l2: 9.19942e+07
# [90]	training's rmse: 12964.7	training's l2: 1.68083e+08	valid_1's rmse: 9273.97	valid_1's l2: 8.60065e+07
# [100]	training's rmse: 12658.1	training's l2: 1.60228e+08	valid_1's rmse: 9110.66	valid_1's l2: 8.30042e+07
# [110]	training's rmse: 12377.1	training's l2: 1.53193e+08	valid_1's rmse: 8940.49	valid_1's l2: 7.99323e+07
# [120]	training's rmse: 12146.5	training's l2: 1.47537e+08	valid_1's rmse: 8733.01	valid_1's l2: 7.62654e+07
# [130]	training's rmse: 11937	training's l2: 1.42492e+08	valid_1's rmse: 8582.11	valid_1's l2: 7.36526e+07
# [140]	training's rmse: 11754	training's l2: 1.38157e+08	valid_1's rmse: 8437.56	valid_1's l2: 7.11924e+07
# [150]	training's rmse: 11568	training's l2: 1.33819e+08	valid_1's rmse: 8338.21	valid_1's l2: 6.95257e+07
# [400]	training's rmse: 9216.57	training's l2: 8.49451e+07	valid_1's rmse: 6946.06	valid_1's l2: 4.82477e+07
# [410]	training's rmse: 9163.59	training's l2: 8.39713e+07	valid_1's rmse: 6927.38	valid_1's l2: 4.79886e+07
# [420]	training's rmse: 9090.28	training's l2: 8.26333e+07	valid_1's rmse: 6903.98	valid_1's l2: 4.76649e+07
# [430]	training's rmse: 9051.09	training's l2: 8.19222e+07	valid_1's rmse: 6875.86	valid_1's l2: 4.72775e+07
# [440]	training's rmse: 9003.61	training's l2: 8.10651e+07	valid_1's rmse: 6850.9	valid_1's l2: 4.69349e+07
# [450]	training's rmse: 8958.13	training's l2: 8.02481e+07	valid_1's rmse: 6831.26	valid_1's l2: 4.66661e+07
# [460]	training's rmse: 8907.53	training's l2: 7.93441e+07	valid_1's rmse: 6783.93	valid_1's l2: 4.60216e+07
# [470]	training's rmse: 8853.7	training's l2: 7.8388e+07	valid_1's rmse: 6750.62	valid_1's l2: 4.55709e+07
# [480]	training's rmse: 8811.99	training's l2: 7.76512e+07	valid_1's rmse: 6735.13	valid_1's l2: 4.5362e+07
# [490]	training's rmse: 8762.07	training's l2: 7.67739e+07	valid_1's rmse: 6706.77	valid_1's l2: 4.49807e+07
# [500]	training's rmse: 8719.79	training's l2: 7.60347e+07	valid_1's rmse: 6693.68	valid_1's l2: 4.48053e+07
# [510]	training's rmse: 8671.32	training's l2: 7.51918e+07	valid_1's rmse: 6673.83	valid_1's l2: 4.454e+07
# [520]	training's rmse: 8624.78	training's l2: 7.43869e+07	valid_1's rmse: 6627.29	valid_1's l2: 4.39209e+07
# [530]	training's rmse: 8592.12	training's l2: 7.38246e+07	valid_1's rmse: 6622.11	valid_1's l2: 4.38523e+07
# [540]	training's rmse: 8544.97	training's l2: 7.30165e+07	valid_1's rmse: 6601.98	valid_1's l2: 4.35861e+07
# [550]	training's rmse: 8515.13	training's l2: 7.25075e+07	valid_1's rmse: 6575.42	valid_1's l2: 4.32361e+07
# [560]	training's rmse: 8474.97	training's l2: 7.18252e+07	valid_1's rmse: 6557.41	valid_1's l2: 4.29997e+07
# [570]	training's rmse: 8442.19	training's l2: 7.12706e+07	valid_1's rmse: 6544.46	valid_1's l2: 4.28299e+07
# [580]	training's rmse: 8415.64	training's l2: 7.08231e+07	valid_1's rmse: 6535.91	valid_1's l2: 4.27182e+07
# [590]	training's rmse: 8376.54	training's l2: 7.01664e+07	valid_1's rmse: 6488.85	valid_1's l2: 4.21051e+07
# [600]	training's rmse: 8341.61	training's l2: 6.95824e+07	valid_1's rmse: 6470.17	valid_1's l2: 4.18631e+07
# [610]	training's rmse: 8305.55	training's l2: 6.89822e+07	valid_1's rmse: 6465.38	valid_1's l2: 4.18011e+07
# [620]	training's rmse: 8272.31	training's l2: 6.84311e+07	valid_1's rmse: 6449.24	valid_1's l2: 4.15926e+07
# [630]	training's rmse: 8230.13	training's l2: 6.7735e+07	valid_1's rmse: 6404.82	valid_1's l2: 4.10217e+07
# [890]	training's rmse: 7542.25	training's l2: 5.68855e+07	valid_1's rmse: 6117.99	valid_1's l2: 3.74298e+07
# [900]	training's rmse: 7519.47	training's l2: 5.65425e+07	valid_1's rmse: 6112.26	valid_1's l2: 3.73597e+07
# [910]	training's rmse: 7495.69	training's l2: 5.61854e+07	valid_1's rmse: 6101.29	valid_1's l2: 3.72258e+07
# [920]	training's rmse: 7474.02	training's l2: 5.5861e+07	valid_1's rmse: 6088.56	valid_1's l2: 3.70706e+07
# [930]	training's rmse: 7454.78	training's l2: 5.55737e+07	valid_1's rmse: 6080.43	valid_1's l2: 3.69716e+07
# [940]	training's rmse: 7435.7	training's l2: 5.52896e+07	valid_1's rmse: 6070.53	valid_1's l2: 3.68513e+07
# [950]	training's rmse: 7419.97	training's l2: 5.50559e+07	valid_1's rmse: 6065.19	valid_1's l2: 3.67866e+07
# [960]	training's rmse: 7398.6	training's l2: 5.47394e+07	valid_1's rmse: 6059.43	valid_1's l2: 3.67167e+07
# [970]	training's rmse: 7375.78	training's l2: 5.44022e+07	valid_1's rmse: 6048.41	valid_1's l2: 3.65833e+07
# [980]	training's rmse: 7352.82	training's l2: 5.4064e+07	valid_1's rmse: 6042.86	valid_1's l2: 3.65162e+07
# [990]	training's rmse: 7337.22	training's l2: 5.38348e+07	valid_1's rmse: 6039.21	valid_1's l2: 3.64721e+07
# [1000]	training's rmse: 7316.15	training's l2: 5.3526e+07	valid_1's rmse: 6032.7	valid_1's l2: 3.63935e+07
# Did not meet early stopping. Best iteration is:
# [1000]	training's rmse: 7316.15	training's l2: 5.3526e+07	valid_1's rmse: 6032.7	valid_1's l2: 3.63935e+07
# --------3번째 fold는 kfold3_gbm.pkl에 저장되었습니다.--------
#
#
# --------4번째 fold의 학습을 시작합니다.--------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.043562 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5829
# [LightGBM] [Info] Number of data points in the train set: 895058, number of used features: 51
# [LightGBM] [Info] Start training from score 62175.746582
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 27345.3	training's l2: 7.47766e+08	valid_1's rmse: 20824.5	valid_1's l2: 4.33662e+08
# [20]	training's rmse: 20330.9	training's l2: 4.13346e+08	valid_1's rmse: 16077	valid_1's l2: 2.58471e+08
# [30]	training's rmse: 17292	training's l2: 2.99014e+08	valid_1's rmse: 13944.6	valid_1's l2: 1.94452e+08
# [40]	training's rmse: 15778.5	training's l2: 2.48962e+08	valid_1's rmse: 13005.4	valid_1's l2: 1.6914e+08
# [50]	training's rmse: 14764.1	training's l2: 2.1798e+08	valid_1's rmse: 12253.6	valid_1's l2: 1.50152e+08
# [60]	training's rmse: 14053.4	training's l2: 1.97497e+08	valid_1's rmse: 11852.4	valid_1's l2: 1.4048e+08
# [70]	training's rmse: 13464.1	training's l2: 1.81283e+08	valid_1's rmse: 11483.3	valid_1's l2: 1.31866e+08
# [80]	training's rmse: 13043.2	training's l2: 1.70124e+08	valid_1's rmse: 11258	valid_1's l2: 1.26743e+08
# [90]	training's rmse: 12665.4	training's l2: 1.60412e+08	valid_1's rmse: 11072.3	valid_1's l2: 1.22596e+08
# [100]	training's rmse: 12362	training's l2: 1.52819e+08	valid_1's rmse: 10918.1	valid_1's l2: 1.19205e+08
# [110]	training's rmse: 12050.1	training's l2: 1.45206e+08	valid_1's rmse: 10752.4	valid_1's l2: 1.15613e+08
# [120]	training's rmse: 11830.2	training's l2: 1.39953e+08	valid_1's rmse: 10633.8	valid_1's l2: 1.13077e+08
# [130]	training's rmse: 11624.5	training's l2: 1.3513e+08	valid_1's rmse: 10525.5	valid_1's l2: 1.10787e+08
# [140]	training's rmse: 11425.2	training's l2: 1.30534e+08	valid_1's rmse: 10428.2	valid_1's l2: 1.08748e+08
# [150]	training's rmse: 11240.3	training's l2: 1.26343e+08	valid_1's rmse: 10318.1	valid_1's l2: 1.06463e+08
# [160]	training's rmse: 11063.6	training's l2: 1.22404e+08	valid_1's rmse: 10253.9	valid_1's l2: 1.05143e+08
# [170]	training's rmse: 10903.5	training's l2: 1.18887e+08	valid_1's rmse: 10168.5	valid_1's l2: 1.03397e+08
# [180]	training's rmse: 10768.2	training's l2: 1.15955e+08	valid_1's rmse: 10130.6	valid_1's l2: 1.0263e+08
# [190]	training's rmse: 10609.1	training's l2: 1.12554e+08	valid_1's rmse: 10026.2	valid_1's l2: 1.00524e+08
# [200]	training's rmse: 10469.9	training's l2: 1.09619e+08	valid_1's rmse: 9957.95	valid_1's l2: 9.91608e+07
# [210]	training's rmse: 10341.7	training's l2: 1.0695e+08	valid_1's rmse: 9894.77	valid_1's l2: 9.79065e+07
# [220]	training's rmse: 10217.7	training's l2: 1.04402e+08	valid_1's rmse: 9829.37	valid_1's l2: 9.66165e+07
# [230]	training's rmse: 10113	training's l2: 1.02273e+08	valid_1's rmse: 9773.87	valid_1's l2: 9.55286e+07
# [240]	training's rmse: 10011.5	training's l2: 1.00229e+08	valid_1's rmse: 9718.03	valid_1's l2: 9.44401e+07
# [250]	training's rmse: 9920.92	training's l2: 9.84247e+07	valid_1's rmse: 9676.69	valid_1's l2: 9.36384e+07
# [260]	training's rmse: 9828.71	training's l2: 9.66036e+07	valid_1's rmse: 9625.76	valid_1's l2: 9.26553e+07
# [270]	training's rmse: 9725.76	training's l2: 9.45905e+07	valid_1's rmse: 9587.97	valid_1's l2: 9.19292e+07
# [280]	training's rmse: 9644.09	training's l2: 9.30085e+07	valid_1's rmse: 9543.08	valid_1's l2: 9.10703e+07
# [290]	training's rmse: 9573.95	training's l2: 9.16605e+07	valid_1's rmse: 9501.19	valid_1's l2: 9.02725e+07
# [300]	training's rmse: 9497.89	training's l2: 9.02099e+07	valid_1's rmse: 9493.74	valid_1's l2: 9.01312e+07
# [310]	training's rmse: 9428.14	training's l2: 8.88898e+07	valid_1's rmse: 9460.68	valid_1's l2: 8.95045e+07
# [320]	training's rmse: 9364.8	training's l2: 8.76994e+07	valid_1's rmse: 9446.33	valid_1's l2: 8.92332e+07
# [330]	training's rmse: 9299.8	training's l2: 8.64862e+07	valid_1's rmse: 9409.97	valid_1's l2: 8.85475e+07
# [340]	training's rmse: 9238.57	training's l2: 8.53512e+07	valid_1's rmse: 9400.81	valid_1's l2: 8.83752e+07
# [350]	training's rmse: 9157.88	training's l2: 8.38667e+07	valid_1's rmse: 9374.51	valid_1's l2: 8.78815e+07
# [360]	training's rmse: 9086.52	training's l2: 8.25649e+07	valid_1's rmse: 9338.09	valid_1's l2: 8.71999e+07
# [370]	training's rmse: 9038.85	training's l2: 8.17008e+07	valid_1's rmse: 9322.2	valid_1's l2: 8.69035e+07
# [380]	training's rmse: 8972.11	training's l2: 8.04987e+07	valid_1's rmse: 9295.6	valid_1's l2: 8.64082e+07
# [390]	training's rmse: 8917.71	training's l2: 7.95256e+07	valid_1's rmse: 9273.58	valid_1's l2: 8.59993e+07
# [400]	training's rmse: 8851.76	training's l2: 7.83536e+07	valid_1's rmse: 9249.07	valid_1's l2: 8.55454e+07
# [410]	training's rmse: 8800.77	training's l2: 7.74536e+07	valid_1's rmse: 9228.73	valid_1's l2: 8.51695e+07
# [420]	training's rmse: 8752.78	training's l2: 7.66111e+07	valid_1's rmse: 9220.41	valid_1's l2: 8.50159e+07
# [430]	training's rmse: 8702.35	training's l2: 7.57309e+07	valid_1's rmse: 9201.7	valid_1's l2: 8.46713e+07
# [440]	training's rmse: 8656.1	training's l2: 7.4928e+07	valid_1's rmse: 9199.05	valid_1's l2: 8.46224e+07
# [450]	training's rmse: 8608.03	training's l2: 7.40981e+07	valid_1's rmse: 9165.85	valid_1's l2: 8.40128e+07
# [460]	training's rmse: 8554.07	training's l2: 7.31721e+07	valid_1's rmse: 9148.74	valid_1's l2: 8.36995e+07
# [470]	training's rmse: 8514.56	training's l2: 7.24978e+07	valid_1's rmse: 9138.96	valid_1's l2: 8.35206e+07
# [480]	training's rmse: 8470.81	training's l2: 7.17546e+07	valid_1's rmse: 9127.6	valid_1's l2: 8.33131e+07
# [490]	training's rmse: 8419.98	training's l2: 7.08961e+07	valid_1's rmse: 9102.99	valid_1's l2: 8.28645e+07
# [500]	training's rmse: 8380.05	training's l2: 7.02253e+07	valid_1's rmse: 9069.24	valid_1's l2: 8.22512e+07
# [510]	training's rmse: 8336.46	training's l2: 6.94965e+07	valid_1's rmse: 9056.27	valid_1's l2: 8.20161e+07
# [520]	training's rmse: 8295.03	training's l2: 6.88074e+07	valid_1's rmse: 9044.91	valid_1's l2: 8.18104e+07
# [530]	training's rmse: 8257.94	training's l2: 6.81935e+07	valid_1's rmse: 9037.03	valid_1's l2: 8.16679e+07
# [540]	training's rmse: 8214.96	training's l2: 6.74856e+07	valid_1's rmse: 9019.34	valid_1's l2: 8.13484e+07
# [550]	training's rmse: 8183.35	training's l2: 6.69672e+07	valid_1's rmse: 9016.26	valid_1's l2: 8.12929e+07
# [560]	training's rmse: 8144.14	training's l2: 6.63271e+07	valid_1's rmse: 8998.17	valid_1's l2: 8.09671e+07
# [570]	training's rmse: 8099.43	training's l2: 6.56007e+07	valid_1's rmse: 8987.14	valid_1's l2: 8.07688e+07
# [580]	training's rmse: 8067.99	training's l2: 6.50924e+07	valid_1's rmse: 8978.51	valid_1's l2: 8.06136e+07
# [590]	training's rmse: 8035.87	training's l2: 6.45752e+07	valid_1's rmse: 8969.35	valid_1's l2: 8.04492e+07
# [600]	training's rmse: 8006.16	training's l2: 6.40986e+07	valid_1's rmse: 8972.49	valid_1's l2: 8.05055e+07
# Early stopping, best iteration is:
# [594]	training's rmse: 8021.53	training's l2: 6.4345e+07	valid_1's rmse: 8964.81	valid_1's l2: 8.03678e+07
# --------4번째 fold는 kfold4_gbm.pkl에 저장되었습니다.--------
#       target
# 0     221036
# 1     320124
# 2     322847
# 3     281652
# 4     230702
# ...      ...
# 9267   83854
# 9268   84728
# 9269   92842
# 9270   85030
# 9271   81890
#
# [9272 rows x 1 columns]

# %% [markdown]
# ### Best 3 K-Fold

# %%
top_3_files = ["kfold2_gbm.pkl", "kfold3_gbm.pkl", "kfold4_gbm.pkl"]
total_predicts = np.zeros(len(X_test))

for file_name in top_3_files:
    gbm_trained = joblib.load(file_name)
    fold_predicts = gbm_trained.predict(X_test)

    total_predicts += fold_predicts / len(top_3_files)

# 앞서 예측한 예측값들을 저장합니다.
preds_df = pd.DataFrame(total_predicts.astype(int), columns=["target"])
preds_df.to_csv('k-fold_output.csv', index=False)

# %% [markdown]
# ### Time series Split

# %%
def time_series_lgb(X, y, test=pd.DataFrame, n_splits=5, gbm=lgb.LGBMRegressor(n_estimators=1000), early_stopping=10, log_evaluation=10):
    # TimeSeriesSplit 함수를 선언합니다.
    kf = TimeSeriesSplit(n_splits=n_splits)
    train_folds = kf.split(X, y)

    fold_save_files = []

    for fold_idx, (train_idx, valid_idx) in enumerate(train_folds):
        display(f"--------{fold_idx}번째 fold의 학습을 시작합니다.--------")

        # index를 통해 fold의 학습세트를 가져옵니다.
        X_train_fold = X.iloc[train_idx, :]
        Y_train_fold = y[train_idx]

        # index를 통해 fold의 평가세트를 가져옵니다.
        X_valid_fold = X.iloc[valid_idx, :]
        Y_valid_fold = y[valid_idx]

        # fold의 데이터로 학습을 진행합니다.
        gbm = lgb.LGBMRegressor(n_estimators=1000)
        gbm.fit(X_train_fold, Y_train_fold,                                               # 학습 데이터를 입력합니다.
            eval_set=[(X_train_fold, Y_train_fold), (X_valid_fold, Y_valid_fold)], # 평가셋을 지정합니다.
            eval_metric ='rmse',                                                               # 평가과정에서 사용할 평가함수를 지정합니다.
            callbacks=[lgb.early_stopping(stopping_rounds=10),                                  # 10번의 성능향상이 없을 경우, 학습을 멈춥니다.
                    lgb.log_evaluation(period=10, show_stdv=True)]                           # 매 iteration마다 학습결과를 출력합니다.
        )

        # 각 fold별 학습한 모델을 저장합니다.
        file_name = f"timeseries_fold{fold_idx}_gbm.pkl"
        joblib.dump(gbm, file_name)
        display(f"--------{fold_idx}번째 fold는 {file_name}에 저장되었습니다.--------\n\n")
        fold_save_files.append(file_name)

    # 저장한 학습모델들을 불러와, Testset에 대한 추론을 진행합니다.
    # 각 fold의 예측결과를 평균을 취하는 방식으로 진행합니다.
    if not test.empty:
        total_predicts = np.zeros(len(X_test))

        for file_name in fold_save_files:
            gbm_trained = joblib.load(file_name)
            fold_predicts = gbm_trained.predict(X_test)

            total_predicts += fold_predicts / len(fold_save_files)
        
        # 앞서 예측한 예측값들을 저장합니다.
        preds_df = pd.DataFrame(total_predicts.astype(int), columns=["target"])
        preds_df.to_csv('time-series_output.csv', index=False)

        return preds_df

# %%
X_train = df_train.drop(['target'], axis=1)
Y_train = df_train['target']

X_train = X_train.sort_values(by='계약년월') # 시간순으로 정렬합니다.
Y_train = Y_train.reindex(X_train.index) # 정렬된 X_train의 인덱스에 맞추어 Y_train도 정렬해줍니다.

X_train = X_train.reset_index(drop=True) # 인덱스를 재정렬 해줍니다.
Y_train = Y_train.reset_index(drop=True)

del X_train['계약년월'] # 시간에 대한 정보를 지웁니다.

X_test = df_test.drop(['target', '계약년월'], axis=1)

time_series_lgb(X_train, Y_train, X_test)
# Out:
# '--------0번째 fold의 학습을 시작합니다.--------'
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011591 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5612
# [LightGBM] [Info] Number of data points in the train set: 186472, number of used features: 51
# [LightGBM] [Info] Start training from score 41193.008543
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 16038.2	training's l2: 2.57222e+08	valid_1's rmse: 16887.1	valid_1's l2: 2.85174e+08
# [20]	training's rmse: 11916.3	training's l2: 1.41999e+08	valid_1's rmse: 12934.1	valid_1's l2: 1.67291e+08
# [30]	training's rmse: 10398.2	training's l2: 1.08122e+08	valid_1's rmse: 11861.9	valid_1's l2: 1.40705e+08
# [40]	training's rmse: 9598.42	training's l2: 9.21296e+07	valid_1's rmse: 11494.3	valid_1's l2: 1.32118e+08
# [50]	training's rmse: 9068.77	training's l2: 8.22425e+07	valid_1's rmse: 11284.1	valid_1's l2: 1.2733e+08
# [60]	training's rmse: 8718.49	training's l2: 7.6012e+07	valid_1's rmse: 11153.4	valid_1's l2: 1.24398e+08
# [70]	training's rmse: 8407.39	training's l2: 7.06843e+07	valid_1's rmse: 11050.5	valid_1's l2: 1.22114e+08
# [80]	training's rmse: 8150.24	training's l2: 6.64265e+07	valid_1's rmse: 10954	valid_1's l2: 1.1999e+08
# [90]	training's rmse: 7946.59	training's l2: 6.31484e+07	valid_1's rmse: 10931.9	valid_1's l2: 1.19505e+08
# [100]	training's rmse: 7746.47	training's l2: 6.00078e+07	valid_1's rmse: 10875.5	valid_1's l2: 1.18277e+08
# [110]	training's rmse: 7578.06	training's l2: 5.7427e+07	valid_1's rmse: 10831.9	valid_1's l2: 1.17331e+08
# [120]	training's rmse: 7433.16	training's l2: 5.52518e+07	valid_1's rmse: 10809.6	valid_1's l2: 1.16847e+08
# [130]	training's rmse: 7285.87	training's l2: 5.30839e+07	valid_1's rmse: 10744.9	valid_1's l2: 1.15452e+08
# [140]	training's rmse: 7156.16	training's l2: 5.12107e+07	valid_1's rmse: 10689.8	valid_1's l2: 1.14272e+08
# [150]	training's rmse: 7036.93	training's l2: 4.95183e+07	valid_1's rmse: 10639.4	valid_1's l2: 1.13197e+08
# [160]	training's rmse: 6919.66	training's l2: 4.78817e+07	valid_1's rmse: 10604.7	valid_1's l2: 1.12459e+08
# [170]	training's rmse: 6826.25	training's l2: 4.65977e+07	valid_1's rmse: 10585.5	valid_1's l2: 1.12052e+08
# [180]	training's rmse: 6729.99	training's l2: 4.52928e+07	valid_1's rmse: 10568.3	valid_1's l2: 1.11689e+08
# [190]	training's rmse: 6641.35	training's l2: 4.41076e+07	valid_1's rmse: 10579.5	valid_1's l2: 1.11926e+08
# Early stopping, best iteration is:
# [181]	training's rmse: 6717.85	training's l2: 4.51295e+07	valid_1's rmse: 10564.9	valid_1's l2: 1.11616e+08
# '--------0번째 fold는 timeseries_fold0_gbm.pkl에 저장되었습니다.--------\n\n'
# '--------1번째 fold의 학습을 시작합니다.--------'
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014357 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5672
# [LightGBM] [Info] Number of data points in the train set: 372942, number of used features: 51
# [LightGBM] [Info] Start training from score 43548.686345
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 16444.7	training's l2: 2.70427e+08	valid_1's rmse: 15577.3	valid_1's l2: 2.42652e+08
# [20]	training's rmse: 12229.2	training's l2: 1.49554e+08	valid_1's rmse: 11783.2	valid_1's l2: 1.38844e+08
# [30]	training's rmse: 10696.6	training's l2: 1.14416e+08	valid_1's rmse: 10723.2	valid_1's l2: 1.14987e+08
# [40]	training's rmse: 9888.36	training's l2: 9.77796e+07	valid_1's rmse: 10153.7	valid_1's l2: 1.03098e+08
# [50]	training's rmse: 9376.89	training's l2: 8.7926e+07	valid_1's rmse: 9803.24	valid_1's l2: 9.61034e+07
# [60]	training's rmse: 8982.81	training's l2: 8.06909e+07	valid_1's rmse: 9539.07	valid_1's l2: 9.09939e+07
# [70]	training's rmse: 8659.36	training's l2: 7.49846e+07	valid_1's rmse: 9334.27	valid_1's l2: 8.71287e+07
# [80]	training's rmse: 8391.02	training's l2: 7.04091e+07	valid_1's rmse: 9134.89	valid_1's l2: 8.34462e+07
# [90]	training's rmse: 8185.47	training's l2: 6.70019e+07	valid_1's rmse: 8982.96	valid_1's l2: 8.06936e+07
# [100]	training's rmse: 7998.01	training's l2: 6.39682e+07	valid_1's rmse: 8829.49	valid_1's l2: 7.79598e+07
# [110]	training's rmse: 7820.83	training's l2: 6.11654e+07	valid_1's rmse: 8729.72	valid_1's l2: 7.6208e+07
# [120]	training's rmse: 7680.8	training's l2: 5.89947e+07	valid_1's rmse: 8640.76	valid_1's l2: 7.46627e+07
# [130]	training's rmse: 7540.44	training's l2: 5.68582e+07	valid_1's rmse: 8544.18	valid_1's l2: 7.3003e+07
# [140]	training's rmse: 7425.72	training's l2: 5.51414e+07	valid_1's rmse: 8471.55	valid_1's l2: 7.17672e+07
# [150]	training's rmse: 7319.69	training's l2: 5.35778e+07	valid_1's rmse: 8405.65	valid_1's l2: 7.0655e+07
# [160]	training's rmse: 7226.26	training's l2: 5.22188e+07	valid_1's rmse: 8344.3	valid_1's l2: 6.96274e+07
# [170]	training's rmse: 7119.52	training's l2: 5.06875e+07	valid_1's rmse: 8278.22	valid_1's l2: 6.85289e+07
# [180]	training's rmse: 7031.83	training's l2: 4.94467e+07	valid_1's rmse: 8224.24	valid_1's l2: 6.76382e+07
# [440]	training's rmse: 5709.05	training's l2: 3.25932e+07	valid_1's rmse: 7494.96	valid_1's l2: 5.61745e+07
# [450]	training's rmse: 5682.87	training's l2: 3.2295e+07	valid_1's rmse: 7490	valid_1's l2: 5.61e+07
# [460]	training's rmse: 5649.82	training's l2: 3.19205e+07	valid_1's rmse: 7475.13	valid_1's l2: 5.58775e+07
# [470]	training's rmse: 5620.32	training's l2: 3.1588e+07	valid_1's rmse: 7460.16	valid_1's l2: 5.5654e+07
# [480]	training's rmse: 5584.59	training's l2: 3.11877e+07	valid_1's rmse: 7438.01	valid_1's l2: 5.53239e+07
# [490]	training's rmse: 5552.28	training's l2: 3.08278e+07	valid_1's rmse: 7424.48	valid_1's l2: 5.51229e+07
# [500]	training's rmse: 5522.81	training's l2: 3.05014e+07	valid_1's rmse: 7410.94	valid_1's l2: 5.4922e+07
# [510]	training's rmse: 5496.53	training's l2: 3.02118e+07	valid_1's rmse: 7410.14	valid_1's l2: 5.49102e+07
# [520]	training's rmse: 5467.64	training's l2: 2.98951e+07	valid_1's rmse: 7400.24	valid_1's l2: 5.47635e+07
# [530]	training's rmse: 5442.2	training's l2: 2.96175e+07	valid_1's rmse: 7392.51	valid_1's l2: 5.46492e+07
# [540]	training's rmse: 5420.88	training's l2: 2.93859e+07	valid_1's rmse: 7390.22	valid_1's l2: 5.46154e+07
# [550]	training's rmse: 5397.24	training's l2: 2.91302e+07	valid_1's rmse: 7380.91	valid_1's l2: 5.44778e+07
# [560]	training's rmse: 5375.51	training's l2: 2.88961e+07	valid_1's rmse: 7377.9	valid_1's l2: 5.44334e+07
# [570]	training's rmse: 5354.03	training's l2: 2.86656e+07	valid_1's rmse: 7379.23	valid_1's l2: 5.4453e+07
# Early stopping, best iteration is:
# [567]	training's rmse: 5358.86	training's l2: 2.87174e+07	valid_1's rmse: 7370.21	valid_1's l2: 5.432e+07
# '--------1번째 fold는 timeseries_fold1_gbm.pkl에 저장되었습니다.--------\n\n'
# '--------2번째 fold의 학습을 시작합니다.--------'
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035599 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5724
# [LightGBM] [Info] Number of data points in the train set: 559412, number of used features: 51
# [LightGBM] [Info] Start training from score 44352.484621
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 16205.1	training's l2: 2.62605e+08	valid_1's rmse: 21648	valid_1's l2: 4.68638e+08
# [20]	training's rmse: 11983.1	training's l2: 1.43594e+08	valid_1's rmse: 16922.5	valid_1's l2: 2.86371e+08
# [30]	training's rmse: 10427.5	training's l2: 1.08733e+08	valid_1's rmse: 15052.6	valid_1's l2: 2.26582e+08
# [40]	training's rmse: 9632.89	training's l2: 9.27925e+07	valid_1's rmse: 13910.6	valid_1's l2: 1.93505e+08
# [50]	training's rmse: 9166.99	training's l2: 8.40337e+07	valid_1's rmse: 13342	valid_1's l2: 1.7801e+08
# [60]	training's rmse: 8793.82	training's l2: 7.73313e+07	valid_1's rmse: 12980	valid_1's l2: 1.6848e+08
# [70]	training's rmse: 8498.49	training's l2: 7.22243e+07	valid_1's rmse: 12684	valid_1's l2: 1.60884e+08
# [80]	training's rmse: 8258.58	training's l2: 6.82041e+07	valid_1's rmse: 12505.2	valid_1's l2: 1.56379e+08
# [90]	training's rmse: 8042.74	training's l2: 6.46856e+07	valid_1's rmse: 12325.1	valid_1's l2: 1.51908e+08
# [100]	training's rmse: 7832.19	training's l2: 6.13432e+07	valid_1's rmse: 12156.6	valid_1's l2: 1.47782e+08
# [110]	training's rmse: 7658.82	training's l2: 5.86575e+07	valid_1's rmse: 12032.2	valid_1's l2: 1.44773e+08
# [120]	training's rmse: 7505.67	training's l2: 5.6335e+07	valid_1's rmse: 11942.3	valid_1's l2: 1.42619e+08
# [130]	training's rmse: 7363.22	training's l2: 5.4217e+07	valid_1's rmse: 11855.5	valid_1's l2: 1.40553e+08
# [140]	training's rmse: 7252.8	training's l2: 5.2603e+07	valid_1's rmse: 11765.2	valid_1's l2: 1.3842e+08
# [150]	training's rmse: 7135.63	training's l2: 5.09172e+07	valid_1's rmse: 11679.5	valid_1's l2: 1.3641e+08
# [160]	training's rmse: 7033.88	training's l2: 4.94755e+07	valid_1's rmse: 11564	valid_1's l2: 1.33727e+08
# [170]	training's rmse: 6905.61	training's l2: 4.76874e+07	valid_1's rmse: 11485	valid_1's l2: 1.31906e+08
# [180]	training's rmse: 6818.88	training's l2: 4.64971e+07	valid_1's rmse: 11377.8	valid_1's l2: 1.29453e+08
# [190]	training's rmse: 6737.41	training's l2: 4.53927e+07	valid_1's rmse: 11307.7	valid_1's l2: 1.27864e+08
# [200]	training's rmse: 6658.1	training's l2: 4.43302e+07	valid_1's rmse: 11228.9	valid_1's l2: 1.26087e+08
# [210]	training's rmse: 6580.11	training's l2: 4.32978e+07	valid_1's rmse: 11164.4	valid_1's l2: 1.24645e+08
# [220]	training's rmse: 6498.03	training's l2: 4.22244e+07	valid_1's rmse: 11104.7	valid_1's l2: 1.23315e+08
# [230]	training's rmse: 6437.18	training's l2: 4.14373e+07	valid_1's rmse: 11065.6	valid_1's l2: 1.22448e+08
# [240]	training's rmse: 6382.63	training's l2: 4.0738e+07	valid_1's rmse: 11009.1	valid_1's l2: 1.21199e+08
# [250]	training's rmse: 6323.84	training's l2: 3.9991e+07	valid_1's rmse: 10963.9	valid_1's l2: 1.20207e+08
# [260]	training's rmse: 6281.11	training's l2: 3.94523e+07	valid_1's rmse: 10927.1	valid_1's l2: 1.19401e+08
# [270]	training's rmse: 6236.7	training's l2: 3.88964e+07	valid_1's rmse: 10875.5	valid_1's l2: 1.18276e+08
# [280]	training's rmse: 6184.55	training's l2: 3.82486e+07	valid_1's rmse: 10856.9	valid_1's l2: 1.17872e+08
# [290]	training's rmse: 6136.88	training's l2: 3.76613e+07	valid_1's rmse: 10842.5	valid_1's l2: 1.17561e+08
# [300]	training's rmse: 6091.94	training's l2: 3.71117e+07	valid_1's rmse: 10827.6	valid_1's l2: 1.17237e+08
# [310]	training's rmse: 6043.95	training's l2: 3.65293e+07	valid_1's rmse: 10784.7	valid_1's l2: 1.16309e+08
# [320]	training's rmse: 6001.21	training's l2: 3.60146e+07	valid_1's rmse: 10765.6	valid_1's l2: 1.15899e+08
# [330]	training's rmse: 5954.63	training's l2: 3.54577e+07	valid_1's rmse: 10728.4	valid_1's l2: 1.15099e+08
# [340]	training's rmse: 5914.57	training's l2: 3.49821e+07	valid_1's rmse: 10700.3	valid_1's l2: 1.14496e+08
# [350]	training's rmse: 5865.49	training's l2: 3.4404e+07	valid_1's rmse: 10672	valid_1's l2: 1.13892e+08
# [360]	training's rmse: 5831.36	training's l2: 3.40047e+07	valid_1's rmse: 10650.1	valid_1's l2: 1.13425e+08
# [370]	training's rmse: 5797.05	training's l2: 3.36058e+07	valid_1's rmse: 10626.9	valid_1's l2: 1.12932e+08
# [380]	training's rmse: 5763.32	training's l2: 3.32159e+07	valid_1's rmse: 10624.6	valid_1's l2: 1.12882e+08
# [390]	training's rmse: 5733	training's l2: 3.28673e+07	valid_1's rmse: 10596.3	valid_1's l2: 1.12281e+08
# [400]	training's rmse: 5698.26	training's l2: 3.24702e+07	valid_1's rmse: 10572.3	valid_1's l2: 1.11773e+08
# [410]	training's rmse: 5664.7	training's l2: 3.20889e+07	valid_1's rmse: 10557.3	valid_1's l2: 1.11458e+08
# [420]	training's rmse: 5636.87	training's l2: 3.17743e+07	valid_1's rmse: 10530.6	valid_1's l2: 1.10894e+08
# [430]	training's rmse: 5602.61	training's l2: 3.13893e+07	valid_1's rmse: 10523.6	valid_1's l2: 1.10746e+08
# [440]	training's rmse: 5573.31	training's l2: 3.10618e+07	valid_1's rmse: 10511.8	valid_1's l2: 1.10498e+08
# [450]	training's rmse: 5542.09	training's l2: 3.07148e+07	valid_1's rmse: 10488.5	valid_1's l2: 1.10009e+08
# [460]	training's rmse: 5517.49	training's l2: 3.04427e+07	valid_1's rmse: 10477.9	valid_1's l2: 1.09786e+08
# [470]	training's rmse: 5477.24	training's l2: 3.00002e+07	valid_1's rmse: 10456.8	valid_1's l2: 1.09345e+08
# [480]	training's rmse: 5445.03	training's l2: 2.96483e+07	valid_1's rmse: 10445.3	valid_1's l2: 1.09104e+08
# [490]	training's rmse: 5414.97	training's l2: 2.93219e+07	valid_1's rmse: 10435.2	valid_1's l2: 1.08893e+08
# [500]	training's rmse: 5387.42	training's l2: 2.90243e+07	valid_1's rmse: 10422	valid_1's l2: 1.08618e+08
# [510]	training's rmse: 5359.58	training's l2: 2.87251e+07	valid_1's rmse: 10406.8	valid_1's l2: 1.083e+08
# [520]	training's rmse: 5336.64	training's l2: 2.84798e+07	valid_1's rmse: 10401	valid_1's l2: 1.0818e+08
# [530]	training's rmse: 5309.59	training's l2: 2.81917e+07	valid_1's rmse: 10394.7	valid_1's l2: 1.08051e+08
# [540]	training's rmse: 5284.86	training's l2: 2.79297e+07	valid_1's rmse: 10379.1	valid_1's l2: 1.07725e+08
# [550]	training's rmse: 5261.02	training's l2: 2.76783e+07	valid_1's rmse: 10362.3	valid_1's l2: 1.07377e+08
# [560]	training's rmse: 5243.91	training's l2: 2.74985e+07	valid_1's rmse: 10348.1	valid_1's l2: 1.07083e+08
# [570]	training's rmse: 5222.18	training's l2: 2.72712e+07	valid_1's rmse: 10327.3	valid_1's l2: 1.06653e+08
# [580]	training's rmse: 5197.99	training's l2: 2.70192e+07	valid_1's rmse: 10329.7	valid_1's l2: 1.06703e+08
# [590]	training's rmse: 5175.39	training's l2: 2.67847e+07	valid_1's rmse: 10314.9	valid_1's l2: 1.06397e+08
# [600]	training's rmse: 5153.06	training's l2: 2.6554e+07	valid_1's rmse: 10306.7	valid_1's l2: 1.06229e+08
# [610]	training's rmse: 5138.01	training's l2: 2.63992e+07	valid_1's rmse: 10324.7	valid_1's l2: 1.066e+08
# Early stopping, best iteration is:
# [602]	training's rmse: 5151.4	training's l2: 2.65369e+07	valid_1's rmse: 10305.9	valid_1's l2: 1.06212e+08
# '--------2번째 fold는 timeseries_fold2_gbm.pkl에 저장되었습니다.--------\n\n'
# '--------3번째 fold의 학습을 시작합니다.--------'
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044835 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5742
# [LightGBM] [Info] Number of data points in the train set: 745882, number of used features: 51
# [LightGBM] [Info] Start training from score 46766.465732
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 17261.3	training's l2: 2.97951e+08	valid_1's rmse: 38963.1	valid_1's l2: 1.51812e+09
# [20]	training's rmse: 12726.4	training's l2: 1.6196e+08	valid_1's rmse: 33142	valid_1's l2: 1.09839e+09
# [30]	training's rmse: 10974.7	training's l2: 1.20444e+08	valid_1's rmse: 30683.7	valid_1's l2: 9.41492e+08
# [40]	training's rmse: 10072	training's l2: 1.01445e+08	valid_1's rmse: 28811.2	valid_1's l2: 8.30083e+08
# [50]	training's rmse: 9490.87	training's l2: 9.00766e+07	valid_1's rmse: 27756.2	valid_1's l2: 7.70406e+08
# [60]	training's rmse: 9103.29	training's l2: 8.28699e+07	valid_1's rmse: 27192	valid_1's l2: 7.39405e+08
# [70]	training's rmse: 8803.82	training's l2: 7.75073e+07	valid_1's rmse: 26727.9	valid_1's l2: 7.14381e+08
# [80]	training's rmse: 8560.98	training's l2: 7.32903e+07	valid_1's rmse: 26356.8	valid_1's l2: 6.94679e+08
# [90]	training's rmse: 8326.15	training's l2: 6.93247e+07	valid_1's rmse: 26110.2	valid_1's l2: 6.81742e+08
# [100]	training's rmse: 8113.24	training's l2: 6.58246e+07	valid_1's rmse: 25964.6	valid_1's l2: 6.74161e+08
# [110]	training's rmse: 7944	training's l2: 6.31072e+07	valid_1's rmse: 25740.3	valid_1's l2: 6.62565e+08
# [120]	training's rmse: 7798.34	training's l2: 6.08141e+07	valid_1's rmse: 25596.1	valid_1's l2: 6.5516e+08
# [130]	training's rmse: 7654.4	training's l2: 5.85899e+07	valid_1's rmse: 25460.9	valid_1's l2: 6.48258e+08
# [140]	training's rmse: 7528.86	training's l2: 5.66837e+07	valid_1's rmse: 25611.6	valid_1's l2: 6.55955e+08
# Early stopping, best iteration is:
# [132]	training's rmse: 7628.34	training's l2: 5.81916e+07	valid_1's rmse: 25441.3	valid_1's l2: 6.47259e+08
# '--------3번째 fold는 timeseries_fold3_gbm.pkl에 저장되었습니다.--------\n\n'
# '--------4번째 fold의 학습을 시작합니다.--------'
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057650 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5776
# [LightGBM] [Info] Number of data points in the train set: 932352, number of used features: 51
# [LightGBM] [Info] Start training from score 51316.276133
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 20674.6	training's l2: 4.27439e+08	valid_1's rmse: 59279	valid_1's l2: 3.514e+09
# [20]	training's rmse: 15350.7	training's l2: 2.35645e+08	valid_1's rmse: 52275.6	valid_1's l2: 2.73273e+09
# [30]	training's rmse: 13179.8	training's l2: 1.73708e+08	valid_1's rmse: 48700.6	valid_1's l2: 2.37175e+09
# [40]	training's rmse: 12019.8	training's l2: 1.44475e+08	valid_1's rmse: 46626.4	valid_1's l2: 2.17402e+09
# [50]	training's rmse: 11240.8	training's l2: 1.26355e+08	valid_1's rmse: 45692.4	valid_1's l2: 2.0878e+09
# [60]	training's rmse: 10711	training's l2: 1.14726e+08	valid_1's rmse: 44921.3	valid_1's l2: 2.01792e+09
# [70]	training's rmse: 10313.8	training's l2: 1.06374e+08	valid_1's rmse: 44530.3	valid_1's l2: 1.98295e+09
# [80]	training's rmse: 9984.83	training's l2: 9.96969e+07	valid_1's rmse: 44215	valid_1's l2: 1.95497e+09
# [90]	training's rmse: 9717.6	training's l2: 9.44318e+07	valid_1's rmse: 44000.9	valid_1's l2: 1.93608e+09
# [100]	training's rmse: 9501.9	training's l2: 9.02861e+07	valid_1's rmse: 43884.8	valid_1's l2: 1.92587e+09
# [110]	training's rmse: 9302.32	training's l2: 8.65331e+07	valid_1's rmse: 43681.1	valid_1's l2: 1.90804e+09
# [120]	training's rmse: 9117.28	training's l2: 8.31249e+07	valid_1's rmse: 43553.3	valid_1's l2: 1.89689e+09
# [130]	training's rmse: 8934.12	training's l2: 7.98185e+07	valid_1's rmse: 43334	valid_1's l2: 1.87784e+09
# [140]	training's rmse: 8796	training's l2: 7.73696e+07	valid_1's rmse: 43278.1	valid_1's l2: 1.87299e+09
# [150]	training's rmse: 8670.39	training's l2: 7.51756e+07	valid_1's rmse: 43112.9	valid_1's l2: 1.85872e+09
# [160]	training's rmse: 8542.08	training's l2: 7.29671e+07	valid_1's rmse: 43036.3	valid_1's l2: 1.85212e+09
# [170]	training's rmse: 8460.6	training's l2: 7.15817e+07	valid_1's rmse: 42829.5	valid_1's l2: 1.83437e+09
# [180]	training's rmse: 8346.42	training's l2: 6.96627e+07	valid_1's rmse: 42776.5	valid_1's l2: 1.82983e+09
# [190]	training's rmse: 8252.56	training's l2: 6.81047e+07	valid_1's rmse: 42656.5	valid_1's l2: 1.81958e+09
# [200]	training's rmse: 8157.5	training's l2: 6.65448e+07	valid_1's rmse: 42594.4	valid_1's l2: 1.81429e+09
# [210]	training's rmse: 8070.21	training's l2: 6.51283e+07	valid_1's rmse: 42361.9	valid_1's l2: 1.79453e+09
# [220]	training's rmse: 7964.9	training's l2: 6.34396e+07	valid_1's rmse: 42260.8	valid_1's l2: 1.78598e+09
# [230]	training's rmse: 7887.01	training's l2: 6.22049e+07	valid_1's rmse: 42205.4	valid_1's l2: 1.7813e+09
# [240]	training's rmse: 7813.59	training's l2: 6.10522e+07	valid_1's rmse: 42135.7	valid_1's l2: 1.77541e+09
# [250]	training's rmse: 7749.33	training's l2: 6.00521e+07	valid_1's rmse: 42123.4	valid_1's l2: 1.77438e+09
# [260]	training's rmse: 7686.19	training's l2: 5.90775e+07	valid_1's rmse: 42049.3	valid_1's l2: 1.76814e+09
# [270]	training's rmse: 7624.06	training's l2: 5.81263e+07	valid_1's rmse: 42012.7	valid_1's l2: 1.76507e+09
# [280]	training's rmse: 7542.66	training's l2: 5.68917e+07	valid_1's rmse: 41940	valid_1's l2: 1.75897e+09
# [290]	training's rmse: 7476.55	training's l2: 5.58988e+07	valid_1's rmse: 41900.9	valid_1's l2: 1.75569e+09
# [300]	training's rmse: 7415.13	training's l2: 5.49841e+07	valid_1's rmse: 41774.4	valid_1's l2: 1.7451e+09
# [310]	training's rmse: 7366.08	training's l2: 5.42592e+07	valid_1's rmse: 41723.3	valid_1's l2: 1.74083e+09
# [320]	training's rmse: 7318.5	training's l2: 5.35605e+07	valid_1's rmse: 41678.7	valid_1's l2: 1.73712e+09
# [330]	training's rmse: 7256.71	training's l2: 5.26599e+07	valid_1's rmse: 41623.4	valid_1's l2: 1.73251e+09
# [340]	training's rmse: 7211.13	training's l2: 5.20005e+07	valid_1's rmse: 41578.7	valid_1's l2: 1.72879e+09
# [350]	training's rmse: 7165.15	training's l2: 5.13394e+07	valid_1's rmse: 41567.3	valid_1's l2: 1.72784e+09
# [360]	training's rmse: 7120.85	training's l2: 5.07064e+07	valid_1's rmse: 41538.1	valid_1's l2: 1.72542e+09
# [370]	training's rmse: 7078.96	training's l2: 5.01117e+07	valid_1's rmse: 41529.8	valid_1's l2: 1.72473e+09
# [380]	training's rmse: 7029.45	training's l2: 4.94132e+07	valid_1's rmse: 41484.3	valid_1's l2: 1.72094e+09
# [390]	training's rmse: 6975.52	training's l2: 4.86579e+07	valid_1's rmse: 41459.2	valid_1's l2: 1.71887e+09
# [400]	training's rmse: 6942.53	training's l2: 4.81987e+07	valid_1's rmse: 41388.3	valid_1's l2: 1.713e+09
# [410]	training's rmse: 6904.63	training's l2: 4.7674e+07	valid_1's rmse: 41360.7	valid_1's l2: 1.71071e+09
# [420]	training's rmse: 6868.38	training's l2: 4.71747e+07	valid_1's rmse: 41342.7	valid_1's l2: 1.70922e+09
# [430]	training's rmse: 6828.97	training's l2: 4.66348e+07	valid_1's rmse: 41285.8	valid_1's l2: 1.70452e+09
# [440]	training's rmse: 6795.86	training's l2: 4.61837e+07	valid_1's rmse: 41307.6	valid_1's l2: 1.70632e+09
# Early stopping, best iteration is:
# [430]	training's rmse: 6828.97	training's l2: 4.66348e+07	valid_1's rmse: 41285.8	valid_1's l2: 1.70452e+09
# '--------4번째 fold는 timeseries_fold4_gbm.pkl에 저장되었습니다.--------\n\n'
#       target
# 0      93920
# 1     122350
# 2     157235
# 3     133352
# 4     100429
# ...      ...
# 9267   44139
# 9268   44222
# 9269   53594
# 9270   45427
# 9271   44206
#
# [9272 rows x 1 columns]
